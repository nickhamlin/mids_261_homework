# %% [markdown]
# #DATASCI W261: Machine Learning at Scale

# %% [markdown]
# Nick Hamlin
# nickhamlin@gmail.com
# Time of Submission: 12:15 AM EST, Tuesday, January 26, 2016
# W261-3, Spring 2016
# Week 3 Homework

# %% [markdown]
# ###Submission Notes:
# - For each problem, I've included a summary of the question as posed in the instructions.  In many cases, I have not included the full text to keep the final submission as uncluttered as possible.  For reference, I've included a link to the original instructions in the "Useful Reference" below.
# - Problem statements are listed in *italics*, while my responses are shown in plain text.
# - I have written driver functions for each problem where a solution is provided in pure Python.  For simplicity, I have omitted them for the sections that use Bash commands either directly or to create files.

# %% [markdown]
# ###Useful References:
# - **[Original Assignment Instructions](https://www.dropbox.com/sh/uev2esasn7bvtnd/AAAlxSC1J3ZHCm7EgkJbemAZa/HW3-Questions.txt?dl=0)**
# - [Counter Example in mrjob](http://nbviewer.jupyter.org/urls/dl.dropbox.com/s/5thl14n4pqvhzt5/Counter.ipynb)
#
# ###Handy Hadoop Links:
# - [Jobtracker](http://localhost:8088/cluster)
# - [Namenode](http://localhost:50070/dfshealth.html#tab-overview)

# %% [markdown]
# ##HW3.0.
#
#
# *What is a merge sort? Where is it used in Hadoop?*
#
# Merge sort is an algorithm that takes two sorted lists and merges them into a single sorted list.  It does this by tracking two pointers at the top of each list. In each iteration, the values of the two pointers are compared, and the smaller of the two is appended to the final list.  Therefore, as the algorithm iterates, the end result is a single sorted list. Hadoop uses merge sort during the shuffle process to take the multiple spill files that are generated for each partion and merge them together before sending them to the combiner.  Merge sort is also used on the reducer side to combine files received from multiple mappers into a single stream.
#
# *How is a combiner function in the context of Hadoop? Give an example where it can be used and justify why it should be used in the context of this problem.*
#
# A combiner function is used to combine records with the same key before they are transferred to the reducer.  For example, in a word count implementation, if a mapper generates two key-value pairs for the same word, a combiner would combine those two records together into a single pair with the same key and a value representing the sum of the two input values.  In Hadoop combiners can be used to reduce the amount of information that must be sent via the network from the mappers to the reducers.  In the previous word count example, if combiners were omitted, the mappers would have to send two pairs across the network.  But, by adding a combiner, only one pair per word needs to be sent.  This reduction in traffic can make a dramatic difference in the processing speed associated with a particular job, especially at large scale.
#
# *What is the Hadoop shuffle?*
#
# The shuffle is the process by which Hadoop sorts the output of the mappers and transfers it to the reducers.  It consists of three main steps: the partition, the sort, and the combine. The partition step takes the output of the mapper and partitions the results, by key, into separate files (one file for each reducer). In the sort step, records within the same partition are sorted.  Finally, the combine step takes records with the same key and merges them together.  Once these steps are completed, the output can then be transferred to the reducer.

# %% [markdown]
# ##HW3.1. Using Counters to do EDA
#
# *Counters are lightweight objects in Hadoop that allow you to keep track of system progress in both the map and reduce stages of processing. By default, Hadoop defines a number of standard counters in "groups"; these show up in the jobtracker webapp, giving you information such as "Map input records", "Map output records", etc.*
#
# *While processing information/data using MapReduce job, it is a challenge to monitor the progress of parallel threads running across nodes of distributed clusters. Moreover, it is also complicated to distinguish between the data that has been processed and the data which is yet to be processed. The MapReduce Framework offers a provision of user-defined Counters, which can be effectively utilized to monitor the progress of data across nodes of distributed clusters.*
#
# *The [consumer complaints](https://www.dropbox.com/s/vbalm3yva2rr86m/Consumer_Complaints.csv?dl=0) dataset consists of diverse consumer complaints, which have been reported across the United States regarding various types of loans.
#
# ###User-defined Counters
#
# *Now, let’s use Hadoop Counters to identify the number of complaints pertaining to debt collection, mortgage and other categories (all other categories get lumped into this one) in the consumer complaints dataset. Basically produce the distribution of the Product column in this dataset using counters (limited to 3 counters here).*
#
# *Hadoop offers Job Tracker, an UI tool to determine the status and statistics of all jobs. Using the job tracker UI, developers can view the Counters that have been created. Screenshot your  job tracker UI as your job completes and include it here. Make sure that your user defined counters are visible.*

# %% [markdown]
# ####HW 3.1 - Mapper and Reducer

# %%
# %%writefile mapper.py
#!/usr/bin/python

#HW 3.1 - Mapper Function Code
import sys
for line in sys.stdin:
    line=line.strip()
    product=line.split(',')[1] #extract product field from second field
    if product=='Debt collection':
        sys.stderr.write("reporter:counter:Debt,Total,1\n")
    if product=='Mortgage':
        sys.stderr.write("reporter:counter:Mortgage,Total,1\n")
    else:
        sys.stderr.write("reporter:counter:Other,Total,1\n")
    print product+'\t1'

# %%
# %%writefile reducer.py
#!/usr/bin/python

#HW 3.1 - Reducer Function Code
import sys
for line in sys.stdin:
    line=line.strip()
    print line

# %%
#Load the input data into HDFS and make sure the output directory is clear
#!bin/hdfs dfs -put Consumer_Complaints.csv
# !bin/hdfs dfs -rm -r hw_3_1_final_output

# %% [markdown]
# ####HW 2.1 - Running the MapReduce Job

# %%
# %%bash
# #Run the job
# bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -file ./mapper.py    -mapper ./mapper.py \
# -file ./reducer.py   -reducer ./reducer.py \
# -input /user/nicholashamlin/Consumer_Complaints.csv \
# -output /user/nicholashamlin/hw_3_1_final_output

# %% [markdown]
# ##HW 3.2 Analyze the performance of your Mappers, Combiners and Reducers using Counters
#
# ###Part A
# *For this brief study the Input file will be one record (the next line only):
# foo foo quux labs foo bar quux*
#
# *Perform a word count analysis of this single record dataset using a Mapper and Reducer based WordCount (i.e., no combiners are used here) using user defined Counters to count up how many time the mapper and reducer are called. What is the value of your user defined Mapper Counter, and Reducer Counter after completing this word count job. The answer  should be 1 and 4 respectively. Please explain.*
#
# #TODO:
# - Confirm proper counter use (increment on print or add reduce tasks?)
# - Add explanation

# %%
! echo "foo foo quux labs foo bar quux" > testfile.txt

# %% [markdown]
# ####HW 3.2 - Mapper and Reducer

# %%
# %%writefile mapper.py
#!/usr/bin/python

#HW 2.2 - Mapper Function Code
import sys
count = 0 #Running total of occurrances for the chosen word
sys.stderr.write("reporter:counter:Mapper,Script Calls,1\n") 
for line in sys.stdin:
    sys.stderr.write("reporter:counter:Mapper,Line Calls,1\n")    
    line=line.strip()
    words=line.split()
    for word in words:
        print word+'\t1'
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/python

#HW 2.2 - Reducer Function Code
import sys
current_word=''
count = 0 #Running total of occurrances for the chosen word
sys.stderr.write("reporter:counter:Reducer,Script Calls,1\n")
for line in sys.stdin:
    line=line.strip().split('\t') #Parse line into a list of fields
    word,sub_count=line
    if current_word==word:
        count+=int(sub_count) #Extract chunk count from the second field of each incoming line
    else:
        if current_word:
            sys.stderr.write("reporter:counter:Reducer,Line Calls,1\n")
            print current_word+'\t'+str(count)
        current_word=word
        count=int(sub_count)
if current_word:
    sys.stderr.write("reporter:counter:Reducer,Line Calls,1\n")
    print current_word+'\t'+str(count)
# Out:
# Overwriting reducer.py

# %%
#Use the command line to test that our modified mapper/reducer files still work right
# !chmod +x ./mapper.py ./reducer.py
# !cat testfile.txt | ./mapper.py | sort| ./reducer.py

# %%
#Load the input data into HDFS and make sure the output directory is clear
#!bin/hdfs dfs -put testfile.txt
# !bin/hdfs dfs -rm -r hw_3_2_a_output
# Out:
# 16/01/31 20:23:52 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:23:53 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted hw_3_2_a_output

# %%
# %%bash
# #Run the job in Hadoop
# bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -file ./mapper.py    -mapper ./mapper.py \
# -file ./reducer.py   -reducer ./reducer.py \
# -input /user/nicholashamlin/testfile.txt -output /user/nicholashamlin/hw_3_2_a_output
# Out:
# packageJobJar: [./mapper.py, ./reducer.py, /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/hadoop-unjar7059521394848543419/] [] /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/streamjob2473049648519019948.jar tmpDir=null
# 16/01/31 20:23:58 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/01/31 20:23:58 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:24:00 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:24:00 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:24:01 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/01/31 20:24:01 INFO mapreduce.JobSubmitter: number of splits:2
# 16/01/31 20:24:01 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1454033924139_0042
# 16/01/31 20:24:01 INFO impl.YarnClientImpl: Submitted application application_1454033924139_0042
# 16/01/31 20:24:01 INFO mapreduce.Job: The url to track the job: http://Nicholass-MacBook-Pro.local:8088/proxy/application_1454033924139_0042/
# 16/01/31 20:24:01 INFO mapreduce.Job: Running job: job_1454033924139_0042
# 16/01/31 20:24:06 INFO mapreduce.Job: Job job_1454033924139_0042 running in uber mode : false
# 16/01/31 20:24:06 INFO mapreduce.Job:  map 0% reduce 0%
# 16/01/31 20:24:12 INFO mapreduce.Job:  map 100% reduce 0%
# 16/01/31 20:24:17 INFO mapreduce.Job:  map 100% reduce 100%
# 16/01/31 20:24:17 INFO mapreduce.Job: Job job_1454033924139_0042 completed successfully
# 16/01/31 20:24:17 INFO mapreduce.Job: Counters: 53
# 	File System Counters
# 		FILE: Number of bytes read=65
# 		FILE: Number of bytes written=329130
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=259
# 		HDFS: Number of bytes written=26
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=7658
# 		Total time spent by all reduces in occupied slots (ms)=2952
# 		Total time spent by all map tasks (ms)=7658
# 		Total time spent by all reduce tasks (ms)=2952
# 		Total vcore-milliseconds taken by all map tasks=7658
# 		Total vcore-milliseconds taken by all reduce tasks=2952
# 		Total megabyte-milliseconds taken by all map tasks=7841792
# 		Total megabyte-milliseconds taken by all reduce tasks=3022848
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=7
# 		Map output bytes=45
# 		Map output materialized bytes=71
# 		Input split bytes=212
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=4
# 		Reduce shuffle bytes=71
# 		Reduce input records=7
# 		Reduce output records=4
# 		Spilled Records=14
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=187
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 		Total committed heap usage (bytes)=557318144
# 	Mapper
# 		Line Calls=1
# 		Script Calls=2
# 	Reducer
# 		Line Calls=4
# 		Script Calls=1
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=47
# 	File Output Format Counters
# 		Bytes Written=26
# 16/01/31 20:24:17 INFO streaming.StreamJob: Output directory: /user/nicholashamlin/hw_3_2_a_output

# %% [markdown]
# ###Part B
# *Please use mulitple mappers and reducers for these jobs (at least 2 mappers and 2 reducers).
# Perform a word count analysis of the Issue column of the Consumer Complaints  Dataset using a Mapper and Reducer based WordCount (i.e., no combiners used anywhere)  using user defined Counters to count up how many time the mapper and reducer are called. What is the value of your user defined Mapper Counter, and Reducer Counter after completing your word count job.*

# %%
# %%writefile mapper.py
#!/usr/bin/python

#HW 3.2.C - Mapper Function Code
import sys
import re
from csv import reader
WORD_RE = re.compile(r"[\w']+")

count = 0 #Running total of occurrances for the chosen word
sys.stderr.write("reporter:counter:Mapper,Script Count,1\n") 
for line in reader(sys.stdin):
    sys.stderr.write("reporter:counter:Mapper,Line Count,1\n")    
    try:
        int(line[0]) #check if the ID field is an integer, skip the record if not
    except ValueError:
        continue
    
    words = re.findall(WORD_RE, line[3])
    for word in words:
        print word.lower()+'\t1'
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/python

#HW 2.2 - Reducer Function Code
import sys
current_word=''
count = 0 #Running total of occurrances for the chosen word
sys.stderr.write("reporter:counter:Reducer,Script Count,1\n")
for line in sys.stdin:
    line=line.strip().split('\t') #Parse line into a list of fields
    word,sub_count=line
    if current_word==word:
        count+=int(sub_count) #Extract chunk count from the second field of each incoming line
    else:
        if current_word:
            sys.stderr.write("reporter:counter:Reducer,Line Count,1\n")
            print current_word+'\t'+str(count)
        current_word=word
        count=int(sub_count)
if current_word:
    sys.stderr.write("reporter:counter:Reducer,Line Count,1\n")
    print current_word+'\t'+str(count)
# Out:
# Overwriting reducer.py

# %%
#Make sure the output directory is clear
# !bin/hdfs dfs -rm -r hw_3_2_b_output

# %%
# %%bash
# #Run the job in Hadoop, this time making sure to specify multiple mappers/reducers
# bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -D mapred.map.tasks=2 \
# -D mapred.reduce.tasks=2 \
# -file ./mapper.py    -mapper ./mapper.py \
# -file ./reducer.py   -reducer ./reducer.py \
# -input /user/nicholashamlin/Consumer_Complaints.csv \
# -output /user/nicholashamlin/hw_3_2_b_output
# Out:
# packageJobJar: [./mapper.py, ./reducer.py, /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/hadoop-unjar5894305380366554869/] [] /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/streamjob8712015224864802186.jar tmpDir=null
# 16/01/31 20:33:18 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/01/31 20:33:18 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:33:19 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:33:19 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:33:20 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/01/31 20:33:20 INFO mapreduce.JobSubmitter: number of splits:2
# 16/01/31 20:33:20 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/01/31 20:33:20 INFO Configuration.deprecation: mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 16/01/31 20:33:20 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1454033924139_0043
# 16/01/31 20:33:20 INFO impl.YarnClientImpl: Submitted application application_1454033924139_0043
# 16/01/31 20:33:20 INFO mapreduce.Job: The url to track the job: http://Nicholass-MacBook-Pro.local:8088/proxy/application_1454033924139_0043/
# 16/01/31 20:33:20 INFO mapreduce.Job: Running job: job_1454033924139_0043
# 16/01/31 20:33:26 INFO mapreduce.Job: Job job_1454033924139_0043 running in uber mode : false
# 16/01/31 20:33:26 INFO mapreduce.Job:  map 0% reduce 0%
# 16/01/31 20:33:39 INFO mapreduce.Job:  map 32% reduce 0%
# 16/01/31 20:33:40 INFO mapreduce.Job:  map 63% reduce 0%
# 16/01/31 20:33:42 INFO mapreduce.Job:  map 100% reduce 0%
# 16/01/31 20:33:51 INFO mapreduce.Job:  map 100% reduce 50%
# 16/01/31 20:33:52 INFO mapreduce.Job:  map 100% reduce 100%
# 16/01/31 20:33:52 INFO mapreduce.Job: Job job_1454033924139_0043 completed successfully
# 16/01/31 20:33:52 INFO mapreduce.Job: Counters: 53
# 	File System Counters
# 		FILE: Number of bytes read=16121335
# 		FILE: Number of bytes written=32681392
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=50910816
# 		HDFS: Number of bytes written=2174
# 		HDFS: Number of read operations=12
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=4
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=2
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=26303
# 		Total time spent by all reduces in occupied slots (ms)=12702
# 		Total time spent by all map tasks (ms)=26303
# 		Total time spent by all reduce tasks (ms)=12702
# 		Total vcore-milliseconds taken by all map tasks=26303
# 		Total vcore-milliseconds taken by all reduce tasks=12702
# 		Total megabyte-milliseconds taken by all map tasks=26934272
# 		Total megabyte-milliseconds taken by all reduce tasks=13006848
# 	Map-Reduce Framework
# 		Map input records=312913
# 		Map output records=1348308
# 		Map output bytes=13424707
# 		Map output materialized bytes=16121347
# 		Input split bytes=234
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=174
# 		Reduce shuffle bytes=16121347
# 		Reduce input records=1348308
# 		Reduce output records=174
# 		Spilled Records=2696616
# 		Shuffled Maps =4
# 		Failed Shuffles=0
# 		Merged Map outputs=4
# 		GC time elapsed (ms)=347
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 		Total committed heap usage (bytes)=687865856
# 	Mapper
# 		Line Count=312913
# 		Script Count=2
# 	Reducer
# 		Line Count=174
# 		Script Count=2
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=50910582
# 	File Output Format Counters
# 		Bytes Written=2174
# 16/01/31 20:33:52 INFO streaming.StreamJob: Output directory: /user/nicholashamlin/hw_3_2_b_output

# %%
# Examine the output of the job in HDFS and print the results
! echo "HW 3.2 PART B RESULTS:"
! echo "10 First Results:"
# !bin/hdfs dfs -cat hw_3_2_b_output/* | head -10
# Out:
# HW 3.2 PART B RESULTS:
# 10 First Results:
# 16/01/31 20:36:00 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# a	3503
# account	57448
# acct	163
# an	2964
# and	16448
# applied	139
# apr	3431
# arbitration	168
# available	274
# bankruptcy	222
# cat: Unable to write to output stream.

# %% [markdown]
# ###Part C
# *Perform a word count analysis of the Issue column of the Consumer Complaints  Dataset using a Mapper, Reducer, and standalone combiner (i.e., not an in-memory combiner) based WordCount using user defined Counters to count up how many time the mapper, combiner, reducer are called. What is the value of your user defined Mapper Counter, and Reducer Counter after completing your word count job.*

# %%
# %%writefile mapper.py
#!/usr/bin/python

#HW 3.2.C - Mapper Function Code
import sys
import re
from csv import reader
WORD_RE = re.compile(r"[\w']+")

count = 0 #Running total of occurrances for the chosen word
sys.stderr.write("reporter:counter:Mapper,Script Count,1\n") 
for line in reader(sys.stdin):
    sys.stderr.write("reporter:counter:Mapper,Line Count,1\n")    
    try:
        int(line[0]) #check if the ID field is an integer, skip the record if not
    except ValueError:
        continue
    
    words = re.findall(WORD_RE, line[3])
    for word in words:
        print word.lower()+'\t1'
# Out:
# Overwriting mapper.py

# %%
# %%writefile combiner.py
#!/usr/bin/python

#HW 2.2 - Combiner Function Code (same as reducer)
import sys
current_word=''
count = 0 #Running total of occurrances for the chosen word
sys.stderr.write("reporter:counter:Combiner,Script Count,1\n")
for line in sys.stdin:
    line=line.strip().split('\t') #Parse line into a list of fields
    word,sub_count=line
    if current_word==word:
        count+=int(sub_count) #Extract chunk count from the second field of each incoming line
    else:
        if current_word:
            sys.stderr.write("reporter:counter:Combiner,Line Count,1\n")
            print current_word+'\t'+str(count)
        current_word=word
        count=int(sub_count)
if current_word:
    sys.stderr.write("reporter:counter:Combiner,Line Count,1\n")
    print current_word+'\t'+str(count)
# Out:
# Writing combiner.py

# %%
! chmod +x ./combiner.py

# %%
# %%writefile reducer.py
#!/usr/bin/python

#HW 2.2 - Reducer Function Code
import sys
current_word=''
count = 0 #Running total of occurrances for the chosen word
sys.stderr.write("reporter:counter:Reducer,Script Count,1\n")
for line in sys.stdin:
    line=line.strip().split('\t') #Parse line into a list of fields
    word,sub_count=line
    if current_word==word:
        count+=int(sub_count) #Extract chunk count from the second field of each incoming line
    else:
        if current_word:
            sys.stderr.write("reporter:counter:Reducer,Line Count,1\n")
            print current_word+'\t'+str(count)
        current_word=word
        count=int(sub_count)
if current_word:
    sys.stderr.write("reporter:counter:Reducer,Line Count,1\n")
    print current_word+'\t'+str(count)
# Out:
# Overwriting reducer.py

# %%
#Make sure combiner is executable and the HDFS output directory is clear
#!chmod +x ./combiner.py
# !bin/hdfs dfs -rm -r hw_3_2_c_output
# Out:
# 16/01/31 20:38:48 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:38:48 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted hw_3_2_c_output

# %%
# %%bash
# #Run the word count job in Hadoop with a single reducer
# bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -D mapred.map.tasks=2 \
# -D mapred.reduce.tasks=2 \
# -file ./mapper.py    -mapper ./mapper.py \
# -file ./reducer.py   -reducer ./reducer.py \
# -file ./combiner.py   -combiner ./combiner.py \
# -input /user/nicholashamlin/Consumer_Complaints.csv \
# -output /user/nicholashamlin/hw_3_2_c_output
# Out:
# packageJobJar: [./mapper.py, ./reducer.py, ./combiner.py, /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/hadoop-unjar2356512219630199513/] [] /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/streamjob7184076909707209707.jar tmpDir=null
# 16/01/31 20:38:55 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/01/31 20:38:55 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:38:56 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:38:56 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:38:57 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/01/31 20:38:57 INFO mapreduce.JobSubmitter: number of splits:2
# 16/01/31 20:38:57 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/01/31 20:38:57 INFO Configuration.deprecation: mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 16/01/31 20:38:57 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1454033924139_0044
# 16/01/31 20:38:57 INFO impl.YarnClientImpl: Submitted application application_1454033924139_0044
# 16/01/31 20:38:57 INFO mapreduce.Job: The url to track the job: http://Nicholass-MacBook-Pro.local:8088/proxy/application_1454033924139_0044/
# 16/01/31 20:38:57 INFO mapreduce.Job: Running job: job_1454033924139_0044
# 16/01/31 20:39:04 INFO mapreduce.Job: Job job_1454033924139_0044 running in uber mode : false
# 16/01/31 20:39:04 INFO mapreduce.Job:  map 0% reduce 0%
# 16/01/31 20:39:17 INFO mapreduce.Job:  map 100% reduce 0%
# 16/01/31 20:39:23 INFO mapreduce.Job:  map 100% reduce 100%
# 16/01/31 20:39:24 INFO mapreduce.Job: Job job_1454033924139_0044 completed successfully
# 16/01/31 20:39:24 INFO mapreduce.Job: Counters: 55
# 	File System Counters
# 		FILE: Number of bytes read=4657
# 		FILE: Number of bytes written=450712
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=50910816
# 		HDFS: Number of bytes written=2174
# 		HDFS: Number of read operations=12
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=4
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=2
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=21694
# 		Total time spent by all reduces in occupied slots (ms)=6437
# 		Total time spent by all map tasks (ms)=21694
# 		Total time spent by all reduce tasks (ms)=6437
# 		Total vcore-milliseconds taken by all map tasks=21694
# 		Total vcore-milliseconds taken by all reduce tasks=6437
# 		Total megabyte-milliseconds taken by all map tasks=22214656
# 		Total megabyte-milliseconds taken by all reduce tasks=6591488
# 	Map-Reduce Framework
# 		Map input records=312913
# 		Map output records=1348308
# 		Map output bytes=13424707
# 		Map output materialized bytes=4669
# 		Input split bytes=234
# 		Combine input records=1348308
# 		Combine output records=324
# 		Reduce input groups=174
# 		Reduce shuffle bytes=4669
# 		Reduce input records=324
# 		Reduce output records=174
# 		Spilled Records=648
# 		Shuffled Maps =4
# 		Failed Shuffles=0
# 		Merged Map outputs=4
# 		GC time elapsed (ms)=273
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 		Total committed heap usage (bytes)=692584448
# 	Combiner
# 		Line Count=324
# 		Script Count=4
# 	Mapper
# 		Line Count=312913
# 		Script Count=2
# 	Reducer
# 		Line Count=174
# 		Script Count=2
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=50910582
# 	File Output Format Counters
# 		Bytes Written=2174
# 16/01/31 20:39:24 INFO streaming.StreamJob: Output directory: /user/nicholashamlin/hw_3_2_c_output

# %%
# Examine the output of the job in HDFS and print the results
! echo "HW 3.2 PART C RESULTS:"
! echo "10 First Results:"
# !bin/hdfs dfs -cat hw_3_2_c_output/* | head -10
# Out:
# HW 3.2 PART C RESULTS:
# 10 First Results:
# 16/01/31 20:39:58 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# a	3503
# account	57448
# acct	163
# an	2964
# and	16448
# applied	139
# apr	3431
# arbitration	168
# available	274
# bankruptcy	222
# cat: Unable to write to output stream.

# %% [markdown]
# ### Part D
# *Using a single reducer: What are the top 50 most frequent terms in your word count analysis? Present the top 50 terms and their frequency and their relative frequency. Present the top 50 terms and their frequency and their relative frequency. If there are ties please sort the tokens in alphanumeric/string order. Present bottom 10 tokens (least frequent items).*

# %%
# %%writefile mapper.py
#!/usr/bin/python

#HW 3.2.C - Mapper Function Code
import sys
import re
from csv import reader
WORD_RE = re.compile(r"[\w']+")

count = 0 #Running total of occurrances for the chosen word
sys.stderr.write("reporter:counter:Mapper,Script Count,1\n") 
for line in reader(sys.stdin):
    sys.stderr.write("reporter:counter:Mapper,Line Count,1\n")    
    try:
        int(line[0]) #check if the ID field is an integer, skip the record if not
    except ValueError:
        continue
    
    words = re.findall(WORD_RE, line[3])
    
    for word in words:
        print word.lower()+'\t1'
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/python

#HW 2.2 - Reducer Function Code
import sys
current_word=''
count = 0 #Running total of occurrances for the chosen word
sys.stderr.write("reporter:counter:Reducer,Script Count,1\n")
for line in sys.stdin:
    line=line.strip().split('\t') #Parse line into a list of fields
    word,sub_count=line
    if current_word==word:
        count+=int(sub_count) #Extract chunk count from the second field of each incoming line
    else:
        if current_word:
            sys.stderr.write("reporter:counter:Reducer,Line Count,1\n")
            print current_word+'\t'+str(count)
        current_word=word
        count=int(sub_count)
if current_word:
    sys.stderr.write("reporter:counter:Reducer,Line Count,1\n")
    print current_word+'\t'+str(count)
# Out:
# Overwriting reducer.py

# %%
#!chmod +x ./mapper2.py ./reducer2.py
# !cat complaints_test.csv | ./mapper.py |sort -k1,1| ./reducer.py #| ./mapper2.py | sort -nr | ./reducer2.py > test_output.txt
#!cat test_output.txt | head -30 
#!rm test_output.txt

# %%
#Load the input data into HDFS and make sure the output directory is clear
#!bin/hdfs dfs -put testfile.txt
# !bin/hdfs dfs -rm -r hw_3_2_d_tmp_output
# Out:
# 16/01/31 20:41:43 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:41:44 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted hw_3_2_d_tmp_output

# %%
# %%bash
# #Run the word count job in Hadoop with a single reducer
# bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -D mapred.map.tasks=2 \
# -D mapred.reduce.tasks=1 \
# -file ./mapper.py    -mapper ./mapper.py \
# -file ./reducer.py   -reducer ./reducer.py \
# -input /user/nicholashamlin/Consumer_Complaints.csv -output /user/nicholashamlin/hw_3_2_d_tmp_output
# Out:
# packageJobJar: [./mapper.py, ./reducer.py, /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/hadoop-unjar4337502379901276165/] [] /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/streamjob1531995029869945457.jar tmpDir=null
# 16/01/31 20:41:49 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/01/31 20:41:49 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:41:51 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:41:51 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:41:51 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/01/31 20:41:51 INFO mapreduce.JobSubmitter: number of splits:2
# 16/01/31 20:41:51 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/01/31 20:41:51 INFO Configuration.deprecation: mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 16/01/31 20:41:52 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1454033924139_0045
# 16/01/31 20:41:52 INFO impl.YarnClientImpl: Submitted application application_1454033924139_0045
# 16/01/31 20:41:52 INFO mapreduce.Job: The url to track the job: http://Nicholass-MacBook-Pro.local:8088/proxy/application_1454033924139_0045/
# 16/01/31 20:41:52 INFO mapreduce.Job: Running job: job_1454033924139_0045
# 16/01/31 20:41:58 INFO mapreduce.Job: Job job_1454033924139_0045 running in uber mode : false
# 16/01/31 20:41:58 INFO mapreduce.Job:  map 0% reduce 0%
# 16/01/31 20:42:08 INFO mapreduce.Job:  map 100% reduce 0%
# 16/01/31 20:42:17 INFO mapreduce.Job:  map 100% reduce 100%
# 16/01/31 20:42:17 INFO mapreduce.Job: Job job_1454033924139_0045 completed successfully
# 16/01/31 20:42:17 INFO mapreduce.Job: Counters: 53
# 	File System Counters
# 		FILE: Number of bytes read=16121329
# 		FILE: Number of bytes written=32571700
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=50910816
# 		HDFS: Number of bytes written=2174
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=17112
# 		Total time spent by all reduces in occupied slots (ms)=5912
# 		Total time spent by all map tasks (ms)=17112
# 		Total time spent by all reduce tasks (ms)=5912
# 		Total vcore-milliseconds taken by all map tasks=17112
# 		Total vcore-milliseconds taken by all reduce tasks=5912
# 		Total megabyte-milliseconds taken by all map tasks=17522688
# 		Total megabyte-milliseconds taken by all reduce tasks=6053888
# 	Map-Reduce Framework
# 		Map input records=312913
# 		Map output records=1348308
# 		Map output bytes=13424707
# 		Map output materialized bytes=16121335
# 		Input split bytes=234
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=174
# 		Reduce shuffle bytes=16121335
# 		Reduce input records=1348308
# 		Reduce output records=174
# 		Spilled Records=2696616
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=210
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 		Total committed heap usage (bytes)=539492352
# 	Mapper
# 		Line Count=312913
# 		Script Count=2
# 	Reducer
# 		Line Count=174
# 		Script Count=1
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=50910582
# 	File Output Format Counters
# 		Bytes Written=2174
# 16/01/31 20:42:17 INFO streaming.StreamJob: Output directory: /user/nicholashamlin/hw_3_2_d_tmp_output

# %%
# %%writefile mapper2.py
#!/usr/bin/python

#HW 2.2.1 - Mapper Function Code
import sys
for line in sys.stdin:
    clean_line=line.strip() #strip whitespace, just to be safe
    fields=clean_line.split('\t') #parse remaining line
    print fields[1]+'\t'+fields[0] #reverse key-value from previous job
# Out:
# Overwriting mapper2.py

# %%
# %%writefile reducer2.py
#!/usr/bin/python

#HW 2.2.1 - Reducer Function Code
import sys
for line in sys.stdin:
    print "%s" % (line.strip()) #pass line through unchanged
# Out:
# Overwriting reducer2.py

# %%
#Load the input data into HDFS and make sure the output directory is clear
#!bin/hdfs dfs -put testfile.txt
# !bin/hdfs dfs -rm -r hw_3_2_d_final_output
# Out:
# 16/01/31 20:43:18 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:43:18 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted hw_3_2_d_final_output

# %%
# %%bash
# #Run the sorting job using the output of the previous data in Hadoop with a single reducer
# bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -D mapred.map.tasks=2 \
# -D mapred.reduce.tasks=1 \
# -D mapred.output.key.comparator.class=org.apache.hadoop.mapred.lib.KeyFieldBasedComparator \
# -D  mapred.text.key.comparator.options=-nr \
# -file ./mapper2.py    -mapper ./mapper2.py \
# -file ./reducer2.py   -reducer ./reducer2.py \
# -input /user/nicholashamlin/hw_3_2_d_tmp_output -output /user/nicholashamlin/hw_3_2_d_final_output
# Out:
# packageJobJar: [./mapper2.py, ./reducer2.py, /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/hadoop-unjar1628639992031426564/] [] /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/streamjob3923105184832607127.jar tmpDir=null
# 16/01/31 20:43:27 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/01/31 20:43:27 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:43:27 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:43:28 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:43:28 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/01/31 20:43:28 INFO mapreduce.JobSubmitter: number of splits:2
# 16/01/31 20:43:28 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/01/31 20:43:28 INFO Configuration.deprecation: mapred.text.key.comparator.options is deprecated. Instead, use mapreduce.partition.keycomparator.options
# 16/01/31 20:43:28 INFO Configuration.deprecation: mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 16/01/31 20:43:28 INFO Configuration.deprecation: mapred.output.key.comparator.class is deprecated. Instead, use mapreduce.job.output.key.comparator.class
# 16/01/31 20:43:28 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1454033924139_0046
# 16/01/31 20:43:28 INFO impl.YarnClientImpl: Submitted application application_1454033924139_0046
# 16/01/31 20:43:28 INFO mapreduce.Job: The url to track the job: http://Nicholass-MacBook-Pro.local:8088/proxy/application_1454033924139_0046/
# 16/01/31 20:43:28 INFO mapreduce.Job: Running job: job_1454033924139_0046
# 16/01/31 20:43:34 INFO mapreduce.Job: Job job_1454033924139_0046 running in uber mode : false
# 16/01/31 20:43:34 INFO mapreduce.Job:  map 0% reduce 0%
# 16/01/31 20:43:43 INFO mapreduce.Job:  map 100% reduce 0%
# 16/01/31 20:43:48 INFO mapreduce.Job:  map 100% reduce 100%
# 16/01/31 20:43:48 INFO mapreduce.Job: Job job_1454033924139_0046 completed successfully
# 16/01/31 20:43:48 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=2528
# 		FILE: Number of bytes written=335091
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=3509
# 		HDFS: Number of bytes written=2174
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=12143
# 		Total time spent by all reduces in occupied slots (ms)=2410
# 		Total time spent by all map tasks (ms)=12143
# 		Total time spent by all reduce tasks (ms)=2410
# 		Total vcore-milliseconds taken by all map tasks=12143
# 		Total vcore-milliseconds taken by all reduce tasks=2410
# 		Total megabyte-milliseconds taken by all map tasks=12434432
# 		Total megabyte-milliseconds taken by all reduce tasks=2467840
# 	Map-Reduce Framework
# 		Map input records=174
# 		Map output records=174
# 		Map output bytes=2174
# 		Map output materialized bytes=2534
# 		Input split bytes=248
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=115
# 		Reduce shuffle bytes=2534
# 		Reduce input records=174
# 		Reduce output records=174
# 		Spilled Records=348
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=192
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 		Total committed heap usage (bytes)=549453824
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=3261
# 	File Output Format Counters
# 		Bytes Written=2174
# 16/01/31 20:43:48 INFO streaming.StreamJob: Output directory: /user/nicholashamlin/hw_3_2_d_final_output

# %%
# Examine the output of the job in HDFS and print the results
! echo "HW 3.2 PART D RESULTS:"
! echo "50 Largest Numbers:"
# !bin/hdfs dfs -cat hw_3_2_d_final_output/* | head -50
! echo "==================================="
! echo "10 Smallest Numbers:"
# !bin/hdfs dfs -cat hw_3_2_d_final_output/* | tail -10
# Out:
# HW 3.2 PART D RESULTS:
# 50 Largest Numbers:
# 16/01/31 20:44:30 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 119630	loan
# 72394	collection
# 70487	foreclosure
# 70487	modification
# 57448	account
# 55251	credit
# 40508	or
# 39993	payments
# 36767	servicing
# 36767	escrow
# 34903	report
# 29133	incorrect
# 29069	information
# 29069	on
# 27874	debt
# 19000	closing
# 18477	not
# 17972	owed
# 17972	cont'd
# 17972	attempts
# 17972	collect
# 16448	and
# 16205	opening
# 16205	management
# 13983	of
# 10731	my
# 10555	withdrawals
# 10555	deposits
# 9484	problems
# 8868	application
# 8671	communication
# 8671	tactics
# 8625	mortgage
# 8625	originator
# 8625	broker
# 8401	to
# 8178	unable
# 8158	billing
# 7886	other
# 7655	verification
# 7655	disclosure
# 6938	disputes
# 6559	reporting
# 6337	lease
# 6248	the
# 5663	low
# 5663	by
# 5663	being
# 5663	funds
# 5663	caused
# ===================================
# 10 Smallest Numbers:
# 16/01/31 20:44:32 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 118	apply
# 98	amount
# 92	credited
# 92	payment
# 75	convenience
# 75	checks
# 71	amt
# 71	day
# 64	disclosures
# 64	missing

# %% [markdown]
# ##HW3.3. Shopping Cart Analysis
# Product Recommendations: The action or practice of selling additional products or services
# to existing customers is called cross-selling. Giving product recommendation is
# one of the examples of cross-selling that are frequently used by online retailers.
# One simple method to give product recommendations is to recommend products that are frequently
# browsed together by the customers.
#
# For this homework use the [online browsing behavior dataset](https://www.dropbox.com/s/zlfyiwa70poqg74/ProductPurchaseData.txt?dl=0)
#
#
# Each line in this dataset represents a browsing session of a customer.
# On each line, each string of 8 characters represents the id of an item browsed during that session. The items are separated by spaces.
#
# Do some exploratory data analysis of this dataset. How many unique items are available from this supplier?
#
# Using a single reducer: Report your findings such as number of unique products; largest basket; report the top 50 most frequently purchased items,  their frequency,  and their relative frequency (break ties by sorting the products alphabetical order) etc. using Hadoop Map-Reduce.

# %% [markdown]
# ### HW 3.3 Mapper and Reducer #1
# The first mapreduce job does the majority of the work.  The mapper emits one space-delimited row with the format {product_id cart_id 1 number_of_products_in_cart] where cart_id is a auto incremented identifier for the row to make the largest cart easy to find at the end.  By pass ing the number of products in the cart along with each product, we can track the largest cart in the reducer as we iterate through all the mapper output.  In addition, we use an order-inversion pattern to emit the total number of all products seen as the first record(s) that the reducer sees.  This enables lazy calculation of product relative frequencies without the need for storing many intermediate values in memory.

# %%
# %%writefile mapper.py
#!/usr/bin/python

#HW 3.3 - Mapper Function Code
import sys
count = 0 #Running total of occurrances for the chosen product
product_count=0
cart_id=1 #The carts don't have IDs of their own, but we can make our own
for line in sys.stdin:
    line=line.strip()
    products=line.split() #split on whitespace

    for product in products:
        product_count+=1
        print product+' '+str(cart_id)+' 1 '+str(len(products)) #emit one row per product per cart
    cart_id+=1
print '**Total '+'0'+' '+str(product_count)+' 0' #emit total number of products for order inversion
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/python

#HW 3.3 - Reducer Function Code
from __future__ import division
import sys
current_product=None
count = 0 #Running total of occurrances for the chosen product
largest_basket_id=0
largest_basket_size=0
unique_products=0
total_product_count=0

for line in sys.stdin:
    #Parse line into fields
    product,cart_id,sub_count,cart_total=line.strip().split(' ')
    sub_count=int(sub_count)
    cart_total=int(cart_total)
    
    if product=='**Total': #Extract total products for order inversion
        total_product_count+=sub_count
        continue
        
    if cart_total>largest_basket_size:
        largest_basket_size=cart_total
        largest_basket_id=cart_id
  
    if current_product==product:
        count+=int(sub_count)
    else:
        if current_product and current_product!='**Total':
            print current_product+'\t'+str(count)+'\t'+str(count/total_product_count)
            unique_products+=1
        current_product=product
        count=int(sub_count)
if current_product:
    print current_product+'\t'+str(count)+'\t'+str(count/total_product_count)
    unique_products+=1
    
print '*Largest Cart\t'+str(largest_basket_id)+'\t'+str(largest_basket_size)
print '*Unique Products'+'\t'+str(unique_products)
#print '*Total Products'+'\t'+str(total_product_count)
# Out:
# Overwriting reducer.py

# %%
# %%writefile mapper2.py
#!/usr/bin/python

largest_basket_id=0
largest_basket_size=0
unique_products=0

#HW 3.3 - Mapper #2 Function Code
import sys
for line in sys.stdin:
    clean_line=line.strip() #strip whitespace, just to be safe
    fields=clean_line.split('\t') #parse remaining line
    if fields[0]=="*Largest Cart":
        largest_basket_id=fields[1]
        largest_basket_size=fields[2]
        continue
    elif fields[0]=="*Unique Products":
        unique_products=fields[1]
        continue
    else:
        try:
            print fields[1]+'\t'+fields[0]+'\t'+fields[2] #reverse key-value from previous job
        except:
            print fields
#pass these values through
print '*Largest Cart\t'+'count\t'+str(largest_basket_size)
print '*Unique Products\t'+'count\t'+str(unique_products)
# Out:
# Overwriting mapper2.py

# %%
# %%writefile reducer2.py
#!/usr/bin/python

#HW 2.2.1 - Reducer Function Code
import sys
for line in sys.stdin:
    print "%s" % (line.strip()) #pass line through unchanged
# Out:
# Overwriting reducer2.py

# %%
#!chmod +x ./mapper2.py ./reducer2.py
#!cat ProductPurchaseData.txt | ./mapper.py |sort  | ./reducer.py | ./mapper2.py | sort -nr | ./reducer2.py  > test_output.txt
# !echo "TOP RESULTS"
# !cat test_output.txt | head -50 |sort -k 1,1nr -k 2,2
# !echo "=================="
# !cat test_output.txt | tail -2 
#!rm test_output.txt

# %%
### Make sure 1st job output directory is clear in HDFS
#!bin/hdfs dfs -put ProductPurchaseData.txt
# !bin/hdfs dfs -rm -r hw_3_3_tmp_output
#!bin/hdfs dfs -ls
# Out:
# 16/01/31 20:45:30 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:45:31 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted hw_3_3_tmp_output

# %%
# %%bash
# #Run the word count job in Hadoop with a single reducer
# bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -D mapred.map.tasks=2 \
# -D mapred.reduce.tasks=1 \
# -file ./mapper.py    -mapper ./mapper.py \
# -file ./reducer.py   -reducer ./reducer.py \
# -input /user/nicholashamlin/ProductPurchaseData.txt -output /user/nicholashamlin/hw_3_3_tmp_output
# Out:
# packageJobJar: [./mapper.py, ./reducer.py, /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/hadoop-unjar3576965742087567407/] [] /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/streamjob7180605897970171506.jar tmpDir=null
# 16/01/31 20:46:00 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/01/31 20:46:00 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:46:01 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:46:02 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:46:02 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/01/31 20:46:02 INFO mapreduce.JobSubmitter: number of splits:2
# 16/01/31 20:46:02 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/01/31 20:46:02 INFO Configuration.deprecation: mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 16/01/31 20:46:02 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1454033924139_0047
# 16/01/31 20:46:03 INFO impl.YarnClientImpl: Submitted application application_1454033924139_0047
# 16/01/31 20:46:03 INFO mapreduce.Job: The url to track the job: http://Nicholass-MacBook-Pro.local:8088/proxy/application_1454033924139_0047/
# 16/01/31 20:46:03 INFO mapreduce.Job: Running job: job_1454033924139_0047
# 16/01/31 20:46:10 INFO mapreduce.Job: Job job_1454033924139_0047 running in uber mode : false
# 16/01/31 20:46:10 INFO mapreduce.Job:  map 0% reduce 0%
# 16/01/31 20:46:19 INFO mapreduce.Job:  map 50% reduce 0%
# 16/01/31 20:46:20 INFO mapreduce.Job:  map 100% reduce 0%
# 16/01/31 20:46:26 INFO mapreduce.Job:  map 100% reduce 100%
# 16/01/31 20:46:26 INFO mapreduce.Job: Job job_1454033924139_0047 completed successfully
# 16/01/31 20:46:26 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=8406183
# 		FILE: Number of bytes written=17141405
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=3462847
# 		HDFS: Number of bytes written=368680
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=14033
# 		Total time spent by all reduces in occupied slots (ms)=4131
# 		Total time spent by all map tasks (ms)=14033
# 		Total time spent by all reduce tasks (ms)=4131
# 		Total vcore-milliseconds taken by all map tasks=14033
# 		Total vcore-milliseconds taken by all reduce tasks=4131
# 		Total megabyte-milliseconds taken by all map tasks=14369792
# 		Total megabyte-milliseconds taken by all reduce tasks=4230144
# 	Map-Reduce Framework
# 		Map input records=31101
# 		Map output records=380826
# 		Map output bytes=7644525
# 		Map output materialized bytes=8406189
# 		Input split bytes=234
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=380577
# 		Reduce shuffle bytes=8406189
# 		Reduce input records=380826
# 		Reduce output records=12594
# 		Spilled Records=761652
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=225
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 		Total committed heap usage (bytes)=548405248
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=3462613
# 	File Output Format Counters
# 		Bytes Written=368680
# 16/01/31 20:46:26 INFO streaming.StreamJob: Output directory: /user/nicholashamlin/hw_3_3_tmp_output

# %%
# !bin/hdfs dfs -rm -r hw_3_3_final_output
# Out:
# 16/01/31 20:46:43 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:46:43 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted hw_3_3_final_output

# %%
# %%bash
# #Run the sorting job using the output of the previous data in Hadoop with a single reducer
# bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -D mapred.map.tasks=2 \
# -D mapred.reduce.tasks=1 \
# -D stream.num.map.output.key.fields=2 \
# -D mapred.output.key.comparator.class=org.apache.hadoop.mapred.lib.KeyFieldBasedComparator \
# -D mapred.text.key.comparator.options='-k1,1nr -k2,2' \
# -file ./mapper2.py    -mapper ./mapper2.py \
# -file ./reducer2.py   -reducer ./reducer2.py \
# -input /user/nicholashamlin/hw_3_3_tmp_output -output /user/nicholashamlin/hw_3_3_final_output
# Out:
# packageJobJar: [./mapper2.py, ./reducer2.py, /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/hadoop-unjar7131952815102305955/] [] /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/streamjob3619285253324436903.jar tmpDir=null
# 16/01/31 20:46:56 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/01/31 20:46:56 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 20:46:57 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:46:57 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 20:46:58 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/01/31 20:46:58 INFO mapreduce.JobSubmitter: number of splits:2
# 16/01/31 20:46:58 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/01/31 20:46:58 INFO Configuration.deprecation: mapred.text.key.comparator.options is deprecated. Instead, use mapreduce.partition.keycomparator.options
# 16/01/31 20:46:58 INFO Configuration.deprecation: mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 16/01/31 20:46:58 INFO Configuration.deprecation: mapred.output.key.comparator.class is deprecated. Instead, use mapreduce.job.output.key.comparator.class
# 16/01/31 20:46:58 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1454033924139_0048
# 16/01/31 20:46:58 INFO impl.YarnClientImpl: Submitted application application_1454033924139_0048
# 16/01/31 20:46:58 INFO mapreduce.Job: The url to track the job: http://Nicholass-MacBook-Pro.local:8088/proxy/application_1454033924139_0048/
# 16/01/31 20:46:58 INFO mapreduce.Job: Running job: job_1454033924139_0048
# 16/01/31 20:47:03 INFO mapreduce.Job: Job job_1454033924139_0048 running in uber mode : false
# 16/01/31 20:47:03 INFO mapreduce.Job:  map 0% reduce 0%
# 16/01/31 20:47:09 INFO mapreduce.Job:  map 100% reduce 0%
# 16/01/31 20:47:14 INFO mapreduce.Job:  map 100% reduce 100%
# 16/01/31 20:47:14 INFO mapreduce.Job: Job job_1454033924139_0048 completed successfully
# 16/01/31 20:47:14 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=393932
# 		FILE: Number of bytes written=1118340
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=373020
# 		HDFS: Number of bytes written=368734
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=7112
# 		Total time spent by all reduces in occupied slots (ms)=3224
# 		Total time spent by all map tasks (ms)=7112
# 		Total time spent by all reduce tasks (ms)=3224
# 		Total vcore-milliseconds taken by all map tasks=7112
# 		Total vcore-milliseconds taken by all reduce tasks=3224
# 		Total megabyte-milliseconds taken by all map tasks=7282688
# 		Total megabyte-milliseconds taken by all reduce tasks=3301376
# 	Map-Reduce Framework
# 		Map input records=12594
# 		Map output records=12596
# 		Map output bytes=368734
# 		Map output materialized bytes=393938
# 		Input split bytes=244
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=12596
# 		Reduce shuffle bytes=393938
# 		Reduce input records=12596
# 		Reduce output records=12596
# 		Spilled Records=25192
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=170
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 		Total committed heap usage (bytes)=545783808
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=372776
# 	File Output Format Counters
# 		Bytes Written=368734
# 16/01/31 20:47:14 INFO streaming.StreamJob: Output directory: /user/nicholashamlin/hw_3_3_final_output

# %%
# Examine the output of the job in HDFS and print the results
! echo "HW 3.3 RESULTS:"
! echo ""
! echo "50 Most Frequent Products:"
! echo "Raw Frequency | Product ID | Relative Frequency"
# !bin/hdfs dfs -cat hw_3_3_final_output/* | head -50
! echo "==================================="
! echo "Summary Stats:"
# We have this odd syntax here because we're trying to do everything in 1 job
# !bin/hdfs dfs -cat hw_3_3_final_output/* | tail -4 |head -2
# Out:
# HW 3.3 RESULTS:
#
# 50 Most Frequent Products:
# Raw Frequency | Product ID | Relative Frequency
# 16/01/31 20:47:28 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 6667	DAI62779	0.0175067747831
# 3881	FRO40251	0.010191059387
# 3875	ELE17451	0.0101753040775
# 3602	GRO73461	0.00945843749344
# 3044	SNA80324	0.00799319370628
# 2851	ELE32164	0.0074863979161
# 2736	DAI75645	0.00718442114993
# 2455	SNA45677	0.0064465474865
# 2330	FRO31317	0.0061183118711
# 2293	DAI85309	0.00602115412894
# 2292	ELE26917	0.00601852824402
# 2233	FRO80039	0.00586360103355
# 2115	GRO21487	0.00555374661261
# 2083	SNA99873	0.00546971829507
# 2004	GRO59710	0.00526227338613
# 1920	GRO71621	0.00504169905258
# 1918	FRO85978	0.00503644728273
# 1840	GRO30386	0.00483162825872
# 1816	ELE74009	0.00476860702057
# 1784	GRO56726	0.00468457870302
# 1773	DAI63921	0.00465569396887
# 1756	GRO46854	0.00461105392517
# 1713	ELE66600	0.00449814087347
# 1712	DAI83733	0.00449551498855
# 1702	FRO32293	0.00446925613932
# 1697	ELE66810	0.0044561267147
# 1646	SNA55762	0.00432220658362
# 1627	DAI22177	0.00427231477008
# 1531	FRO78087	0.00402022981745
# 1516	ELE99737	0.0039808415436
# 1489	ELE34057	0.00390994265067
# 1489	GRO94758	0.00390994265067
# 1436	FRO35904	0.00377077074974
# 1420	FRO53271	0.00372875659097
# 1407	SNA93860	0.00369462008697
# 1390	SNA90094	0.00364998004327
# 1352	GRO38814	0.00355019641619
# 1345	ELE56788	0.00353181522173
# 1321	GRO61133	0.00346879398357
# 1316	DAI88807	0.00345566455896
# 1316	ELE74482	0.00345566455896
# 1311	ELE59935	0.00344253513434
# 1295	SNA96271	0.00340052097557
# 1290	DAI43223	0.00338739155095
# 1289	ELE91337	0.00338476566603
# 1275	GRO15017	0.0033480032771
# 1261	DAI31081	0.00331124088818
# 1220	GRO81087	0.00320357960633
# 1219	DAI22896	0.0032009537214
# 1214	GRO85051	0.00318782429679
# cat: Unable to write to output stream.
# ===================================
# Summary Stats:
# 16/01/31 20:47:30 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# *Largest Cart	count	37
# *Unique Products	count	12592

# %% [markdown]
# ##HW3.4. Pairs
# (Computationally prohibitive but then again Hadoop can handle this)
#
# Suppose we want to recommend new products to the customer based on the products they
# have already browsed on the online website. Write a map-reduce program
# to find products which are frequently browsed together. Fix the support count (cooccurence count) to s = 100
# (i.e. product pairs need to occur together at least 100 times to be considered frequent)
# and find pairs of items (sometimes referred to itemsets of size 2 in association rule mining) that have a support count of 100 or more.
#
# List the top 50 product pairs with corresponding support count (aka frequency), and relative frequency or support (number of records where they coccur, the number of records where they coccur/the number of baskets in the dataset)  in decreasing order of support  for frequent (100>count) itemsets of size 2.
#
# Use the Pairs pattern (lecture 3)  to  extract these frequent itemsets of size 2. Free free to use combiners if they bring value. Instrument your code with counters for count the number of times your mapper, combiner and reducers are called.
#
# Please output records of the following form for the top 50 pairs (itemsets of size 2):
#
#       item1, item2, support count, support
#
# Fix the ordering of the pairs lexicographically (left to right),
# and break ties in support (between pairs, if any exist)
# by taking the first ones in lexicographically increasing order.
#
# Report  the compute time for the Pairs job. Describe the computational setup used (E.g., single computer; dual core; linux, number of mappers, number of reducers)
# Instrument your mapper, combiner, and reducer to count how many times each is called using Counters and report these counts.

# %%
# %%writefile mapper.py
#!/usr/bin/python

#HW 3.4 - Mapper Function Code
import sys
number_of_carts=0
sys.stderr.write("reporter:counter:Mapper,Script Count,1\n") 

for line in sys.stdin:
    line=line.strip()
    products=line.split() #split on whitespace

    for i,product in enumerate(products):
        product_a=product
        for product_b in products[i+1:]:
            output=sorted([product_a,product_b])
            sys.stderr.write("reporter:counter:Mapper,Line Count,1\n") 
            print output[0]+'\t'+output[1]+'\t1'
    number_of_carts+=1

print '**Total'+'\t'+'**Total'+'\t'+str(number_of_carts)
sys.stderr.write("reporter:counter:Mapper,Line Count,1\n")
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/python

#HW 3.4 - Reducer Function Code
from __future__ import division
import sys

sys.stderr.write("reporter:counter:Reducer,Script Count,1\n") 

s=100 #cutoff for "frequent"
current_product_a=None
current_product_b=None
count = 100 #Running total of occurrances for the chosen product

number_of_carts=0

for line in sys.stdin:
    #Parse line into fields
    product_a,product_b,support=line.strip().split('\t')
    support=int(support)
    
    if product_a=='**Total' and product_b=='**Total': #Extract total products for order inversion
        number_of_carts+=support
        continue
  
    if current_product_a==product_a and current_product_b==product_b:
        count+=support
    else:
        if current_product_a and current_product_b and current_product_a!='**Total':
            if count>=s:
                print current_product_a+'\t'+current_product_b+'\t'+str(count)+'\t'+str(count/number_of_carts)
                sys.stderr.write("reporter:counter:Reducer,Line Count,1\n") 
        current_product_a=product_a
        current_product_b=product_b
        count=support
if current_product_a and current_product_b and current_product_a!='**Total':
    if count>=s:
        print current_product_a+'\t'+current_product_b+'\t'+str(count)+'\t'+str(count/number_of_carts)
        sys.stderr.write("reporter:counter:Reducer,Line Count,1\n")
# Out:
# Overwriting reducer.py

# %%
# %%writefile mapper2.py
#!/usr/bin/python

#HW 3.4 - Mapper #2 Function Code
import sys
for line in sys.stdin:
    clean_line=line.strip() #strip whitespace, just to be safe
    fields=clean_line.split('\t') #parse remaining line
    print fields[2]+'\t'+fields[0]+'\t'+fields[1]+'\t'+fields[3]
# Out:
# Overwriting mapper2.py

# %%
# %%writefile reducer2.py
#!/usr/bin/python

#HW 3.4 - Reducer #2 Function Code
import sys
for line in sys.stdin:
    clean_line=line.strip() #strip whitespace, just to be safe
    fields=clean_line.split('\t') #parse remaining line
    print fields[1]+'\t'+fields[2]+'\t'+fields[0]+'\t'+fields[3]
# Out:
# Overwriting reducer2.py

# %%
#!chmod +x ./mapper2.py ./reducer2.py
#!cat ProductPurchaseData.txt  | ./mapper.py |sort -k 1,1 -k2,2 | ./reducer.py | sort -k 3,3nr -k 1,1 -k 2,2
# !cat purchase_test.txt  | ./mapper.py |sort -k 1,1 -k2,2 | ./reducer.py #| sort -k 3,3nr -k 1,1 -k 2,2
#!cat purchase_test.txt | ./mapper.py |sort  | ./reducer.py | ./mapper2.py | sort -nr | ./reducer2.py  > test_output.txt
#!rm test_output.txt

# %%
### Make sure 1st job output directory is clear in HDFS
#!bin/hdfs dfs -put purchase_test.txt
# !bin/hdfs dfs -rm -r hw_3_4_tmp_output
#!bin/hdfs dfs -ls
# Out:
# 16/01/31 22:03:12 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 22:03:12 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted hw_3_4_tmp_output

# %%
# %%bash
# #Run the word count job in Hadoop with a single reducer
# time bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -D stream.num.map.output.key.fields=2 \
# -D mapred.output.key.comparator.class=org.apache.hadoop.mapred.lib.KeyFieldBasedComparator \
# -D mapred.text.key.comparator.options='-k1,1 -k2,2' \
# -file ./mapper.py    -mapper ./mapper.py \
# -file ./reducer.py   -reducer ./reducer.py \
# -input /user/nicholashamlin/ProductPurchaseData.txt -output /user/nicholashamlin/hw_3_4_tmp_output
# Out:
# packageJobJar: [./mapper.py, ./reducer.py, /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/hadoop-unjar6807334711811766599/] [] /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/streamjob1180096362960781858.jar tmpDir=null
# 16/01/31 22:03:14 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/01/31 22:03:15 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 22:03:16 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 22:03:16 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 22:03:17 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/01/31 22:03:17 INFO mapreduce.JobSubmitter: number of splits:2
# 16/01/31 22:03:17 INFO Configuration.deprecation: mapred.text.key.comparator.options is deprecated. Instead, use mapreduce.partition.keycomparator.options
# 16/01/31 22:03:17 INFO Configuration.deprecation: mapred.output.key.comparator.class is deprecated. Instead, use mapreduce.job.output.key.comparator.class
# 16/01/31 22:03:17 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1454033924139_0060
# 16/01/31 22:03:17 INFO impl.YarnClientImpl: Submitted application application_1454033924139_0060
# 16/01/31 22:03:17 INFO mapreduce.Job: The url to track the job: http://Nicholass-MacBook-Pro.local:8088/proxy/application_1454033924139_0060/
# 16/01/31 22:03:17 INFO mapreduce.Job: Running job: job_1454033924139_0060
# 16/01/31 22:03:24 INFO mapreduce.Job: Job job_1454033924139_0060 running in uber mode : false
# 16/01/31 22:03:24 INFO mapreduce.Job:  map 0% reduce 0%
# 16/01/31 22:03:34 INFO mapreduce.Job:  map 100% reduce 0%
# 16/01/31 22:03:44 INFO mapreduce.Job:  map 100% reduce 68%
# 16/01/31 22:03:47 INFO mapreduce.Job:  map 100% reduce 69%
# 16/01/31 22:03:51 INFO mapreduce.Job:  map 100% reduce 70%
# 16/01/31 22:03:54 INFO mapreduce.Job:  map 100% reduce 71%
# 16/01/31 22:04:00 INFO mapreduce.Job:  map 100% reduce 72%
# 16/01/31 22:04:03 INFO mapreduce.Job:  map 100% reduce 73%
# 16/01/31 22:04:09 INFO mapreduce.Job:  map 100% reduce 74%
# 16/01/31 22:04:24 INFO mapreduce.Job:  map 100% reduce 75%
# 16/01/31 22:04:27 INFO mapreduce.Job:  map 100% reduce 76%
# 16/01/31 22:04:33 INFO mapreduce.Job:  map 100% reduce 77%
# 16/01/31 22:04:39 INFO mapreduce.Job:  map 100% reduce 78%
# 16/01/31 22:04:45 INFO mapreduce.Job:  map 100% reduce 79%
# 16/01/31 22:04:48 INFO mapreduce.Job:  map 100% reduce 80%
# 16/01/31 22:04:57 INFO mapreduce.Job:  map 100% reduce 81%
# 16/01/31 22:05:03 INFO mapreduce.Job:  map 100% reduce 82%
# 16/01/31 22:05:09 INFO mapreduce.Job:  map 100% reduce 83%
# 16/01/31 22:05:15 INFO mapreduce.Job:  map 100% reduce 84%
# 16/01/31 22:05:18 INFO mapreduce.Job:  map 100% reduce 85%
# 16/01/31 22:05:24 INFO mapreduce.Job:  map 100% reduce 86%
# 16/01/31 22:05:30 INFO mapreduce.Job:  map 100% reduce 87%
# 16/01/31 22:05:33 INFO mapreduce.Job:  map 100% reduce 88%
# 16/01/31 22:05:39 INFO mapreduce.Job:  map 100% reduce 89%
# 16/01/31 22:05:42 INFO mapreduce.Job:  map 100% reduce 90%
# 16/01/31 22:05:48 INFO mapreduce.Job:  map 100% reduce 91%
# 16/01/31 22:05:54 INFO mapreduce.Job:  map 100% reduce 92%
# 16/01/31 22:06:00 INFO mapreduce.Job:  map 100% reduce 93%
# 16/01/31 22:06:03 INFO mapreduce.Job:  map 100% reduce 94%
# 16/01/31 22:06:09 INFO mapreduce.Job:  map 100% reduce 95%
# 16/01/31 22:06:13 INFO mapreduce.Job:  map 100% reduce 96%
# 16/01/31 22:06:19 INFO mapreduce.Job:  map 100% reduce 97%
# 16/01/31 22:06:25 INFO mapreduce.Job:  map 100% reduce 98%
# 16/01/31 22:06:28 INFO mapreduce.Job:  map 100% reduce 99%
# 16/01/31 22:06:31 INFO mapreduce.Job:  map 100% reduce 100%
# 16/01/31 22:06:33 INFO mapreduce.Job: Job job_1454033924139_0060 completed successfully
# 16/01/31 22:06:33 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=42881266
# 		FILE: Number of bytes written=86092990
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=3462847
# 		HDFS: Number of bytes written=51765
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=17422
# 		Total time spent by all reduces in occupied slots (ms)=175226
# 		Total time spent by all map tasks (ms)=17422
# 		Total time spent by all reduce tasks (ms)=175226
# 		Total vcore-milliseconds taken by all map tasks=17422
# 		Total vcore-milliseconds taken by all reduce tasks=175226
# 		Total megabyte-milliseconds taken by all map tasks=17840128
# 		Total megabyte-milliseconds taken by all reduce tasks=179431424
# 	Map-Reduce Framework
# 		Map input records=31101
# 		Map output records=349725
# 		Map output bytes=42019724
# 		Map output materialized bytes=42881272
# 		Input split bytes=234
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=331779
# 		Reduce shuffle bytes=42881272
# 		Reduce input records=349725
# 		Reduce output records=1334
# 		Spilled Records=699450
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=268
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 		Total committed heap usage (bytes)=589299712
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=3462613
# 	File Output Format Counters
# 		Bytes Written=51765
# 16/01/31 22:06:33 INFO streaming.StreamJob: Output directory: /user/nicholashamlin/hw_3_4_tmp_output
#
# real	3m19.113s
# user	0m6.135s
# sys	0m0.549s

# %%
# !bin/hdfs dfs -rm -r hw_3_4_final_output
# Out:
# 16/01/31 22:09:38 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 22:09:39 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted hw_3_4_final_output

# %%
# %%bash
# #Run the sorting job using the output of the previous data in Hadoop with a single reducer
# #cat test_output.txt | head -50 |sort -k 1,1nr -k 2,2
# time bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -D stream.num.map.output.key.fields=3 \
# -D mapred.output.key.comparator.class=org.apache.hadoop.mapred.lib.KeyFieldBasedComparator \
# -D mapred.text.key.comparator.options='-k 1,1nr -k 2,2 -k 3,3' \
# -file ./mapper2.py    -mapper ./mapper2.py \
# -file ./reducer2.py   -reducer ./reducer2.py \
# -input /user/nicholashamlin/hw_3_4_tmp_output -output /user/nicholashamlin/hw_3_4_final_output
# Out:
# packageJobJar: [./mapper2.py, ./reducer2.py, /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/hadoop-unjar8653705034829116473/] [] /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/streamjob5471912145651923136.jar tmpDir=null
# 16/01/31 22:09:43 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/01/31 22:09:43 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 22:09:44 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 22:09:44 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 22:09:45 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/01/31 22:09:45 INFO mapreduce.JobSubmitter: number of splits:2
# 16/01/31 22:09:45 INFO Configuration.deprecation: mapred.text.key.comparator.options is deprecated. Instead, use mapreduce.partition.keycomparator.options
# 16/01/31 22:09:45 INFO Configuration.deprecation: mapred.output.key.comparator.class is deprecated. Instead, use mapreduce.job.output.key.comparator.class
# 16/01/31 22:09:45 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1454033924139_0061
# 16/01/31 22:09:45 INFO impl.YarnClientImpl: Submitted application application_1454033924139_0061
# 16/01/31 22:09:45 INFO mapreduce.Job: The url to track the job: http://Nicholass-MacBook-Pro.local:8088/proxy/application_1454033924139_0061/
# 16/01/31 22:09:45 INFO mapreduce.Job: Running job: job_1454033924139_0061
# 16/01/31 22:09:51 INFO mapreduce.Job: Job job_1454033924139_0061 running in uber mode : false
# 16/01/31 22:09:51 INFO mapreduce.Job:  map 0% reduce 0%
# 16/01/31 22:09:56 INFO mapreduce.Job:  map 100% reduce 0%
# 16/01/31 22:10:01 INFO mapreduce.Job:  map 100% reduce 100%
# 16/01/31 22:10:01 INFO mapreduce.Job: Job job_1454033924139_0061 completed successfully
# 16/01/31 22:10:01 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=54439
# 		FILE: Number of bytes written=439384
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=56105
# 		HDFS: Number of bytes written=51765
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=7054
# 		Total time spent by all reduces in occupied slots (ms)=2272
# 		Total time spent by all map tasks (ms)=7054
# 		Total time spent by all reduce tasks (ms)=2272
# 		Total vcore-milliseconds taken by all map tasks=7054
# 		Total vcore-milliseconds taken by all reduce tasks=2272
# 		Total megabyte-milliseconds taken by all map tasks=7223296
# 		Total megabyte-milliseconds taken by all reduce tasks=2326528
# 	Map-Reduce Framework
# 		Map input records=1334
# 		Map output records=1334
# 		Map output bytes=51765
# 		Map output materialized bytes=54445
# 		Input split bytes=244
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1334
# 		Reduce shuffle bytes=54445
# 		Reduce input records=1334
# 		Reduce output records=1334
# 		Spilled Records=2668
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=165
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 		Total committed heap usage (bytes)=549978112
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=55861
# 	File Output Format Counters
# 		Bytes Written=51765
# 16/01/31 22:10:01 INFO streaming.StreamJob: Output directory: /user/nicholashamlin/hw_3_4_final_output
#
# real	0m19.318s
# user	0m4.968s
# sys	0m0.343s

# %%
# Examine the output of the job in HDFS and print the results
! echo "HW 3.4 RESULTS:"
! echo ""
! echo "50 Most Frequent Pairs:"
! echo "Product 1   |   Product 2 | Raw Freq. | Support "
# !bin/hdfs dfs -cat hw_3_4_final_output/* | head -50
# Out:
# HW 3.4 RESULTS:
#
# 50 Most Frequent Pairs:
# Product 1   |   Product 2 | Raw Freq. | Support
# 16/01/31 22:11:55 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# DAI62779	ELE17451	1592	0.0511880646925
# FRO40251	SNA80324	1412	0.0454004694383
# DAI75645	FRO40251	1254	0.0403202469374
# FRO40251	GRO85051	1213	0.0390019613517
# DAI62779	GRO73461	1139	0.0366226166361
# DAI75645	SNA80324	1130	0.0363332368734
# DAI62779	FRO40251	1070	0.0344040384554
# DAI62779	SNA80324	923	0.0296775023311
# DAI62779	DAI85309	918	0.0295167357963
# ELE32164	GRO59710	911	0.0292916626475
# DAI62779	DAI75645	882	0.0283592167454
# FRO40251	GRO73461	882	0.0283592167454
# DAI62779	ELE92920	877	0.0281984502106
# FRO40251	FRO92469	835	0.026848011318
# DAI62779	ELE32164	832	0.0267515513971
# DAI75645	GRO73461	712	0.0228931545609
# DAI43223	ELE32164	711	0.022861001254
# DAI62779	GRO30386	709	0.02279669464
# ELE17451	FRO40251	697	0.0224108549564
# DAI85309	ELE99737	659	0.0211890292917
# DAI62779	ELE26917	650	0.020899649529
# GRO21487	GRO73461	631	0.0202887366966
# DAI62779	SNA45677	604	0.0194205974084
# ELE17451	SNA80324	597	0.0191955242597
# DAI62779	GRO71621	595	0.0191312176457
# DAI62779	SNA55762	593	0.0190669110318
# DAI62779	DAI83733	586	0.018841837883
# ELE17451	GRO73461	580	0.0186489180412
# GRO73461	SNA80324	562	0.0180701585158
# DAI62779	GRO59710	561	0.0180380052088
# DAI62779	FRO80039	550	0.0176843188322
# DAI75645	ELE17451	547	0.0175878589113
# DAI62779	SNA93860	537	0.0172663258416
# DAI55148	DAI62779	526	0.016912639465
# DAI43223	GRO59710	512	0.0164624931674
# ELE17451	ELE32164	511	0.0164303398605
# DAI62779	SNA18336	506	0.0162695733256
# ELE32164	GRO73461	486	0.0156265071863
# DAI62779	FRO78087	482	0.0154978939584
# DAI85309	ELE17451	482	0.0154978939584
# DAI62779	GRO94758	479	0.0154014340375
# DAI62779	GRO21487	471	0.0151442075817
# GRO85051	SNA80324	471	0.0151442075817
# ELE17451	GRO30386	468	0.0150477476608
# FRO85978	SNA95666	463	0.014886981126
# DAI62779	FRO19221	462	0.014854827819
# DAI62779	GRO46854	461	0.0148226745121
# DAI43223	DAI62779	459	0.0147583678981
# ELE92920	SNA18336	455	0.0146297546703
# DAI88079	FRO40251	446	0.0143403749076
# cat: Unable to write to output stream.

# %% [markdown]
# ##HW3.5. Stripes
# *Repeat 3.4 using the stripes design pattern for finding cooccuring pairs.*
#
# *Report  the compute times for stripes job versus the Pairs job. Describe the computational setup used (E.g., single computer; dual core; linux, number of mappers, number of reducers)*
#
# *Instrument your mapper, combiner, and reducer to count how many times each is called using Counters and report these counts. Discuss the differences in these counts between the Pairs and Stripes jobs*

# %%
# %%writefile mapper.py
#!/usr/bin/python

#HW 3.4 - Mapper Function Code
import sys
#sys.stderr.write("reporter:counter:Mapper,Script Count,1\n") 
number_of_carts=0
for line in sys.stdin:
    line=line.strip()
    products=line.split() #split on whitespace
    try:
        products.sort()
    except:
        pass #don't bother sorting if there aren't any pairs
    for i,product_a in enumerate(products):
        line_output={}
        for product_b in products[i+1:]:
            try:
                line_output[product_b]+=1
            except KeyError:
                line_output[product_b]=1
        if line_output.keys():
            print product_a+'\t'+str(line_output)
            #sys.stderr.write("reporter:counter:Mapper,Line Count,1\n") 
    
    number_of_carts+=1
print '**Total'+'\t{"number_of_carts":'+str(number_of_carts)+'}'
#sys.stderr.write("reporter:counter:Mapper,Line Count,1\n")
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/python

#HW 3.4 - Reducer Function Code
from __future__ import division
import sys
from collections import Counter, OrderedDict
#sys.stderr.write("reporter:counter:Reducer,Script Count,1\n") 
s=100 #cutoff for "frequent"
current_product_dict=Counter({})
current_product=None
count = 0 #Running total of occurrances for the chosen product

number_of_carts=0

for line in sys.stdin:
    #Parse line into fields
    product,product_dict=line.strip().split('\t')
    product_dict=Counter(eval(product_dict))
    
    if product=='**Total': #Extract total products for order inversion
        number_of_carts+=product_dict['number_of_carts']
        continue
  
    if current_product==product:
        current_product_dict+=Counter(product_dict)
    else:
        if current_product and current_product!='**Total':
            for i in OrderedDict(sorted(current_product_dict.items())):
                if current_product_dict[i]>=s:
                    #sys.stderr.write("reporter:counter:Reducer,Line Count,1\n") 
                    print current_product+'\t'+i+'\t'+str(current_product_dict[i])+'\t'+str(current_product_dict[i]/number_of_carts)
        current_product=product
        current_product_dict=product_dict

if current_product and current_product!='**Total':
    for i in OrderedDict(sorted(current_product_dict.items())):
        if current_product_dict[i]>=s:
            #sys.stderr.write("reporter:counter:Reducer,Line Count,1\n") 
            print current_product+'\t'+i+'\t'+str(current_product_dict[i])+'\t'+str(current_product_dict[i]/number_of_carts)
        
#print '*Total Products'+'\t'+str(total_product_count)
# Out:
# Overwriting reducer.py

# %%
#!chmod +x ./mapper2.py ./reducer2.py
#!echo "FRO11987 ELE17451 ELE89019 FRO11987 SNA90258 GRO99222 " | ./mapper.py |sort | ./reducer.py
# !cat purchase_test.txt  | ./mapper.py |sort -k 1,1 -k2,2 | ./reducer.py #| sort -k 3,3nr -k 1,1 -k 2,2
#!cat purchase_test.txt | ./mapper.py |sort  | ./reducer.py # | ./mapper2.py | sort -nr | ./reducer2.py  > test_output.txt
#!rm test_output.txt
# Out:
# DAI14125	DAI37607	1	0.02
# DAI14125	ELE11375	1	0.02
# DAI14125	ELE12792	1	0.02
# DAI14125	ELE17451	1	0.02
# DAI14125	ELE20166	1	0.02
# DAI14125	ELE28573	1	0.02
# DAI14125	FRO18919	1	0.02
# DAI14125	FRO40066	1	0.02
# DAI14125	FRO78087	1	0.02
# DAI14125	GRO55423	1	0.02
# DAI14125	GRO86568	1	0.02
# DAI14125	GRO94758	1	0.02
# DAI14125	SNA69641	1	0.02
# DAI14125	SNA90258	1	0.02
# DAI14125	SNA93641	1	0.02
# DAI17810	DAI22896	1	0.02
# DAI17810	DAI38969	1	0.02
# DAI17810	DAI50913	1	0.02
# DAI17810	ELE17451	1	0.02
# DAI17810	FRO17376	1	0.02
# DAI17810	FRO18919	1	0.02
# DAI17810	FRO47475	1	0.02
# DAI17810	FRO78087	1	0.02
# DAI17810	GRO39357	1	0.02
# DAI17810	GRO73461	1	0.02
# DAI17810	GRO75578	1	0.02
# DAI17810	SNA90258	1	0.02
# DAI17810	SNA99873	1	0.02
# DAI18334	DAI22534	1	0.02
# DAI18334	DAI22896	1	0.02
# DAI18334	DAI35347	2	0.04
# DAI18334	DAI38156	1	0.02
# DAI18334	DAI55911	1	0.02
# DAI18334	DAI59119	1	0.02
# DAI18334	DAI95741	2	0.04
# DAI18334	ELE17451	2	0.04
# DAI18334	ELE26917	2	0.04
# DAI18334	ELE73246	1	0.02
# DAI18334	ELE96863	2	0.04
# DAI18334	FRO13639	1	0.02
# DAI18334	FRO19520	1	0.02
# DAI18334	FRO24098	2	0.04
# DAI18334	FRO31317	1	0.02
# DAI18334	FRO38366	2	0.04
# DAI18334	FRO87042	1	0.02
# DAI18334	GRO48498	2	0.04
# DAI18334	GRO73461	2	0.04
# DAI18334	GRO91763	1	0.02
# DAI18334	GRO99222	2	0.04
# DAI18334	SNA26720	1	0.02
# DAI18334	SNA40380	1	0.02
# DAI18334	SNA55952	1	0.02
# DAI18334	SNA59903	1	0.02
# DAI18334	SNA63157	1	0.02
# DAI18334	SNA70487	2	0.04
# DAI18334	SNA72163	1	0.02
# DAI18334	SNA84406	1	0.02
# DAI22177	DAI22896	4	0.08
# DAI22177	DAI35347	1	0.02
# DAI22177	DAI38156	1	0.02
# DAI22177	DAI46755	1	0.02
# DAI22177	DAI49199	1	0.02
# DAI22177	DAI59119	1	0.02
# DAI32480	DAI63921	1	0.02
# DAI32480	ELE17451	1	0.02
# DAI32480	ELE26917	1	0.02
# DAI32480	FRO31317	1	0.02
# DAI32480	GRO32230	1	0.02
# DAI32480	GRO34288	1	0.02
# DAI32480	GRO68850	1	0.02
# DAI32480	GRO99222	1	0.02
# DAI32480	SNA14713	1	0.02
# DAI32480	SNA17715	1	0.02
# DAI32480	SNA55762	1	0.02
# DAI32480	SNA80064	1	0.02
# DAI32480	SNA86836	1	0.02
# DAI32480	SNA99873	1	0.02
# DAI33885	DAI44355	1	0.02
# DAI33885	ELE12792	1	0.02
# DAI33885	ELE13292	1	0.02
# DAI33885	ELE20166	1	0.02
# DAI33885	ELE22574	1	0.02
# DAI33885	ELE27376	1	0.02
# DAI33885	GRO71615	1	0.02
# DAI33885	GRO92942	1	0.02
# DAI33885	SNA56035	1	0.02
# DAI35347	DAI36452	1	0.02
# DAI35347	DAI38156	3	0.06
# DAI35347	DAI47060	1	0.02
# DAI35347	DAI48891	2	0.04
# DAI35347	DAI50921	1	0.02
# DAI35347	DAI55911	1	0.02
# DAI35347	DAI59119	1	0.02
# DAI35347	DAI59508	1	0.02
# DAI35347	DAI62779	4	0.08
# DAI35347	DAI63921	2	0.04
# DAI35347	DAI73122	1	0.02
# DAI35347	DAI87514	1	0.02
# DAI35347	DAI93692	2	0.04
# DAI35347	DAI95741	2	0.04
# DAI35347	DAI95860	1	0.02
# DAI35347	ELE11375	1	0.02
# DAI35347	ELE12792	1	0.02
# DAI35347	ELE17451	10	0.2
# DAI35347	ELE18435	1	0.02
# DAI35347	ELE21353	1	0.02
# DAI35347	ELE26917	6	0.12
# DAI35347	ELE28573	1	0.02
# DAI35347	ELE30182	2	0.04
# DAI35347	ELE37798	3	0.06
# DAI35347	ELE49863	1	0.02
# DAI35347	ELE52966	1	0.02
# DAI35347	ELE59935	3	0.06
# DAI35347	ELE64231	1	0.02
# DAI35347	ELE66067	1	0.02
# DAI35347	ELE73246	2	0.04
# DAI35347	ELE79816	1	0.02
# DAI35347	ELE89019	1	0.02
# DAI35347	ELE96863	5	0.1
# DAI35347	FRO13639	1	0.02
# DAI35347	FRO19520	2	0.04
# DAI35347	FRO24098	5	0.1
# DAI35347	FRO31317	3	0.06
# DAI35347	FRO32293	1	0.02
# DAI35347	FRO36081	1	0.02
# DAI35347	FRO38366	2	0.04
# DAI35347	FRO40251	1	0.02
# DAI35347	FRO41069	2	0.04
# DAI35347	FRO43226	1	0.02
# DAI35347	FRO53137	1	0.02
# DAI35347	FRO70489	1	0.02
# DAI35347	FRO71213	1	0.02
# DAI35347	FRO75418	1	0.02
# DAI35347	FRO78087	1	0.02
# DAI35347	FRO78994	1	0.02
# DAI35347	FRO87042	1	0.02
# DAI35347	FRO92261	1	0.02
# DAI35347	FRO98184	2	0.04
# DAI35347	FRO98878	3	0.06
# DAI35347	GRO12935	3	0.06
# DAI35347	GRO15017	2	0.04
# DAI35347	GRO32230	1	0.02
# DAI35347	GRO34288	2	0.04
# DAI35347	GRO36567	1	0.02
# DAI35347	GRO38636	1	0.02
# DAI35347	GRO48282	1	0.02
# DAI35347	GRO48498	2	0.04
# DAI35347	GRO49037	2	0.04
# DAI35347	GRO56989	4	0.08
# DAI35347	GRO59710	1	0.02
# DAI35347	GRO68850	1	0.02
# DAI35347	GRO69543	1	0.02
# DAI35347	GRO73461	3	0.06
# DAI35347	GRO81874	1	0.02
# DAI35347	GRO91763	1	0.02
# DAI35347	GRO99222	6	0.12
# DAI35347	SNA14713	3	0.06
# DAI35347	SNA17715	3	0.06
# DAI35347	SNA26720	1	0.02
# DAI35347	SNA40380	1	0.02
# DAI35347	SNA44593	1	0.02
# DAI35347	SNA45033	1	0.02
# DAI35347	SNA45677	2	0.04
# DAI35347	SNA55762	1	0.02
# DAI35347	SNA55952	3	0.06
# DAI35347	SNA58915	2	0.04
# DAI35347	SNA59903	1	0.02
# DAI35347	SNA63157	3	0.06
# DAI35347	SNA69641	1	0.02
# DAI35347	SNA70487	4	0.08
# DAI35347	SNA72163	1	0.02
# DAI35347	SNA80064	1	0.02
# DAI35347	SNA80192	1	0.02
# DAI35347	SNA81153	1	0.02
# DAI35347	SNA84406	1	0.02
# DAI35347	SNA86836	1	0.02
# DAI35347	SNA89670	1	0.02
# DAI35347	SNA93730	1	0.02
# DAI35347	SNA93860	1	0.02
# DAI35347	SNA94781	1	0.02
# DAI35347	SNA99873	2	0.04
# DAI36452	DAI50921	1	0.02
# DAI36452	DAI62779	1	0.02
# DAI36452	ELE17451	1	0.02
# DAI36452	ELE59935	1	0.02
# DAI36452	FRO32293	1	0.02
# DAI36452	FRO41069	1	0.02
# DAI36452	FRO71213	1	0.02
# DAI36452	FRO78994	1	0.02
# DAI36452	GRO12935	1	0.02
# DAI36452	GRO56989	1	0.02
# DAI36452	SNA14713	1	0.02
# DAI36452	SNA45677	1	0.02
# DAI36452	SNA58915	1	0.02
# DAI36452	SNA81153	1	0.02
# DAI36452	SNA89670	1	0.02
# DAI36452	SNA93730	1	0.02
# DAI37607	ELE12792	1	0.02
# DAI37607	ELE20166	1	0.02
# DAI37607	FRO40066	1	0.02
# DAI37607	GRO55423	1	0.02
# DAI37607	GRO86568	1	0.02
# DAI37607	GRO94758	1	0.02
# DAI37607	SNA93641	1	0.02
# DAI38156	DAI55911	1	0.02
# DAI38156	DAI59119	1	0.02
# DAI38156	DAI93692	1	0.02
# DAI38156	DAI95741	1	0.02
# DAI38156	ELE17451	2	0.04
# DAI38156	ELE18435	1	0.02
# DAI38156	ELE26917	3	0.06
# DAI38156	ELE30182	1	0.02
# DAI38156	ELE37798	1	0.02
# DAI38156	ELE59935	1	0.02
# DAI38156	ELE96863	2	0.04
# DAI38156	FRO13639	1	0.02
# DAI38156	FRO19520	2	0.04
# DAI38156	FRO24098	3	0.06
# DAI38156	FRO31317	1	0.02
# DAI38156	FRO38366	1	0.02
# DAI38156	FRO41069	1	0.02
# DAI38156	FRO87042	1	0.02
# DAI38156	FRO98184	1	0.02
# DAI38156	FRO98878	2	0.04
# DAI38156	GRO48498	1	0.02
# DAI38156	GRO56989	1	0.02
# DAI55911	SNA72163	1	0.02
# DAI58079	ELE11474	1	0.02
# DAI58079	ELE28189	1	0.02
# DAI58079	ELE63685	1	0.02
# DAI58079	GRO56989	1	0.02
# DAI58079	GRO94758	1	0.02
# DAI58079	SNA99873	1	0.02
# DAI59119	DAI95741	1	0.02
# DAI59119	ELE17451	2	0.04
# DAI59119	ELE20196	1	0.02
# DAI59119	ELE26917	1	0.02
# DAI59119	ELE89019	1	0.02
# DAI59119	ELE96863	1	0.02
# DAI59119	FRO13639	1	0.02
# DAI59119	FRO19520	1	0.02
# DAI59119	FRO24098	1	0.02
# DAI59119	FRO31317	2	0.04
# DAI59119	FRO38366	1	0.02
# DAI59119	FRO60023	1	0.02
# DAI59119	FRO87042	1	0.02
# DAI59119	GRO48498	1	0.02
# DAI59119	GRO73461	1	0.02
# DAI59119	GRO94047	1	0.02
# DAI59119	GRO99222	1	0.02
# DAI59119	SNA55952	1	0.02
# DAI59119	SNA59903	1	0.02
# DAI59119	SNA70487	1	0.02
# DAI59119	SNA72163	1	0.02
# DAI59508	DAI62779	1	0.02
# DAI59508	DAI73122	1	0.02
# DAI59508	ELE12792	1	0.02
# DAI59508	ELE17451	1	0.02
# DAI59508	ELE49863	1	0.02
# DAI59508	ELE64231	1	0.02
# DAI59508	ELE96863	1	0.02
# DAI59508	FRO40251	1	0.02
# DAI59508	FRO43226	1	0.02
# DAI59508	FRO53137	1	0.02
# DAI59508	FRO78087	1	0.02
# DAI59508	FRO78994	1	0.02
# DAI59508	FRO98878	1	0.02
# DAI59508	FRO99756	1	0.02
# DAI59508	GRO12935	1	0.02
# DAI59508	GRO34288	1	0.02
# DAI59508	GRO49037	1	0.02
# DAI59508	GRO56989	1	0.02
# DAI59508	GRO69543	1	0.02
# DAI59508	GRO81874	1	0.02
# DAI59508	GRO84328	1	0.02
# DAI59508	GRO85051	1	0.02
# DAI59508	GRO93077	1	0.02
# DAI59508	SNA14713	1	0.02
# DAI59508	SNA45677	1	0.02
# DAI59508	SNA63157	1	0.02
# DAI59508	SNA69641	1	0.02
# DAI59508	SNA70487	1	0.02
# DAI59508	SNA89670	1	0.02
# DAI62779	DAI63921	2	0.04
# DAI62779	DAI73122	1	0.02
# DAI62779	ELE12792	1	0.02
# DAI62779	ELE14480	1	0.02
# DAI62779	ELE17451	9	0.18
# DAI62779	ELE20398	1	0.02
# DAI62779	ELE21353	1	0.02
# DAI62779	ELE26917	1	0.02
# DAI62779	ELE41924	1	0.02
# DAI62779	ELE49863	1	0.02
# DAI62779	ELE59935	2	0.04
# DAI62779	ELE64231	1	0.02
# DAI62779	ELE68605	1	0.02
# DAI62779	ELE79816	1	0.02
# DAI62779	ELE86561	1	0.02
# DAI62779	ELE89019	1	0.02
# DAI62779	ELE96863	1	0.02
# DAI62779	FRO31317	6	0.12
# DAI62779	FRO32293	1	0.02
# DAI62779	FRO35353	2	0.04
# DAI62779	FRO37380	1	0.02
# DAI62779	FRO40251	1	0.02
# DAI62779	FRO41069	2	0.04
# DAI62779	FRO43226	1	0.02
# DAI62779	FRO44363	1	0.02
# DAI69239	SNA14713	1	0.02
# DAI69239	SNA93641	1	0.02
# DAI69239	SNA99873	1	0.02
# DAI73122	ELE12792	1	0.02
# DAI73122	ELE17451	1	0.02
# DAI73122	ELE49863	1	0.02
# DAI73122	ELE64231	1	0.02
# DAI73122	ELE96863	1	0.02
# DAI73122	FRO53137	1	0.02
# DAI73122	FRO98878	1	0.02
# DAI73122	GRO34288	1	0.02
# DAI73122	GRO49037	1	0.02
# DAI73122	GRO69543	1	0.02
# DAI73122	GRO81874	1	0.02
# DAI73122	SNA14713	1	0.02
# DAI73122	SNA45677	1	0.02
# DAI73122	SNA63157	1	0.02
# DAI73122	SNA69641	1	0.02
# DAI73122	SNA70487	1	0.02
# DAI84001	ELE11468	1	0.02
# DAI84001	ELE20166	1	0.02
# DAI84001	ELE91337	1	0.02
# DAI84001	FRO35353	1	0.02
# DAI84001	GRO17442	1	0.02
# DAI84001	SNA30579	1	0.02
# DAI84001	SNA45677	1	0.02
# DAI84001	SNA58915	1	0.02
# DAI84001	SNA77101	1	0.02
# DAI87514	DAI92253	2	0.04
# DAI87514	DAI93692	2	0.04
# DAI87514	ELE17451	3	0.06
# DAI87514	ELE26917	2	0.04
# DAI87514	ELE30182	1	0.02
# DAI87514	ELE37798	1	0.02
# DAI87514	ELE52966	1	0.02
# DAI87514	ELE82555	2	0.04
# DAI87514	FRO82427	2	0.04
# DAI87514	FRO98184	1	0.02
# DAI87514	GRO12935	3	0.06
# DAI87514	GRO15017	1	0.02
# DAI87514	GRO36567	2	0.04
# DAI87514	GRO48282	3	0.06
# DAI87514	GRO56989	1	0.02
# DAI87514	GRO59710	1	0.02
# DAI87514	GRO73461	2	0.04
# DAI87514	GRO99222	3	0.06
# DAI87514	SNA17715	3	0.06
# DAI87514	SNA44593	1	0.02
# DAI87514	SNA47306	1	0.02
# DAI87514	SNA55952	2	0.04
# DAI87514	SNA94781	3	0.06
# DAI88808	ELE17451	1	0.02
# DAI88808	ELE52446	1	0.02
# DAI88808	ELE96863	1	0.02
# DAI88808	FRO16142	1	0.02
# DAI88808	FRO18919	1	0.02
# DAI88808	FRO41069	1	0.02
# DAI88808	FRO70974	1	0.02
# DAI88808	FRO75418	1	0.02
# DAI88808	GRO30386	1	0.02
# DAI88808	GRO36567	1	0.02
# DAI88808	GRO49037	1	0.02
# DAI88808	GRO73461	1	0.02
# DAI88808	GRO99222	1	0.02
# DAI88808	SNA47306	1	0.02
# DAI88808	SNA80192	1	0.02
# DAI88808	SNA90258	1	0.02
# DAI88808	SNA91554	1	0.02
# DAI91290	ELE17451	1	0.02
# DAI91290	ELE59935	1	0.02
# DAI91290	ELE89019	1	0.02
# DAI91290	FRO62970	1	0.02
# DAI91290	FRO78087	1	0.02
# DAI91290	FRO79301	1	0.02
# DAI91290	SNA83730	1	0.02
# DAI91290	SNA85034	1	0.02
# DAI91535	ELE17451	2	0.04
# DAI91535	ELE37798	1	0.02
# DAI91535	ELE66810	1	0.02
# DAI91535	ELE94711	1	0.02
# DAI91535	FRO76833	1	0.02
# DAI91535	FRO81176	2	0.04
# DAI91535	GRO56989	1	0.02
# DAI91535	GRO73461	1	0.02
# DAI91535	GRO94758	2	0.04
# DAI91535	GRO99222	1	0.02
# DAI91535	SNA69641	1	0.02
# DAI91535	SNA80192	2	0.04
# DAI91535	SNA85662	1	0.02
# DAI91535	SNA90258	1	0.02
# DAI92253	DAI93692	2	0.04
# DAI92253	ELE17451	2	0.04
# DAI92253	ELE26917	1	0.02
# DAI92253	ELE37798	1	0.02
# DAI92253	ELE82555	2	0.04
# DAI92253	FRO82427	2	0.04
# DAI92253	GRO12935	2	0.04
# DAI92253	GRO36567	2	0.04
# DAI92253	GRO48282	2	0.04
# DAI92253	GRO56989	1	0.02
# DAI92253	GRO73461	1	0.02
# DAI92253	GRO99222	2	0.04
# DAI92253	SNA17715	2	0.04
# DAI92253	SNA47306	1	0.02
# DAI92253	SNA55952	2	0.04
# DAI92253	SNA94781	2	0.04
# DAI93692	ELE17451	5	0.1
# DAI93692	ELE26917	2	0.04
# DAI93692	ELE37798	3	0.06
# DAI93692	ELE59935	1	0.02
# DAI93692	ELE66067	1	0.02
# DAI93692	ELE73246	1	0.02
# DAI93692	ELE82555	2	0.04
# DAI93692	ELE89019	1	0.02
# DAI93692	ELE96863	1	0.02
# DAI93692	FRO13639	1	0.02
# DAI93692	FRO19520	2	0.04
# DAI93692	FRO24098	2	0.04
# DAI93692	FRO36081	1	0.02
# DAI93692	FRO75418	1	0.02
# DAI93692	FRO82427	2	0.04
# DAI93692	FRO92261	1	0.02
# DAI93692	FRO98878	2	0.04
# DAI93692	GRO12935	2	0.04
# DAI93692	GRO36567	4	0.08
# DAI93692	GRO48282	2	0.04
# DAI93692	GRO49037	2	0.04
# DAI93692	GRO56989	3	0.06
# DAI93692	GRO73461	2	0.04
# DAI93692	GRO99222	4	0.08
# DAI93692	SNA17715	2	0.04
# DAI93692	SNA47306	2	0.04
# DAI93692	SNA55952	5	0.1
# DAI93692	SNA63157	2	0.04
# DAI93692	SNA80192	1	0.02
# DAI93692	SNA94781	2	0.04
# DAI95741	ELE17451	3	0.06
# DAI95741	ELE26917	2	0.04
# DAI95741	ELE37798	1	0.02
# DAI95741	ELE73246	1	0.02
# DAI95741	ELE96863	2	0.04
# DAI95741	FRO13639	1	0.02
# DAI95741	FRO19520	1	0.02
# DAI95741	FRO24098	2	0.04
# DAI95741	FRO31317	1	0.02
# DAI95741	FRO38366	2	0.04
# DAI95741	FRO78087	1	0.02
# DAI95741	FRO86643	1	0.02
# DAI95741	FRO87042	1	0.02
# DAI95741	GRO39357	1	0.02
# DAI95741	GRO39369	1	0.02
# DAI95741	GRO48498	2	0.04
# DAI95741	GRO56989	1	0.02
# DAI95741	GRO73461	2	0.04
# DAI95741	GRO75578	1	0.02
# DAI95741	GRO91763	1	0.02
# DAI95741	GRO99222	2	0.04
# DAI95741	SNA11465	1	0.02
# DAI95741	SNA26720	1	0.02
# DAI95741	SNA40380	1	0.02
# DAI95741	SNA55952	1	0.02
# DAI95741	SNA59903	1	0.02
# SNA45677	SNA70487	1	0.02
# SNA45677	SNA77101	1	0.02
# SNA45677	SNA81153	1	0.02
# SNA45677	SNA89670	1	0.02
# SNA45677	SNA93730	1	0.02
# SNA46341	SNA93641	1	0.02
# SNA46341	SNA99873	1	0.02
# SNA47306	SNA55952	2	0.04
# SNA47306	SNA63157	1	0.02
# SNA47306	SNA80192	1	0.02
# SNA47306	SNA90258	1	0.02
# SNA47306	SNA91554	1	0.02
# SNA47306	SNA94781	1	0.02
# SNA54161	SNA83730	1	0.02
# SNA55762	SNA80064	1	0.02
# SNA55762	SNA86836	1	0.02
# SNA55762	SNA99873	1	0.02
# SNA55952	SNA59903	1	0.02
# SNA55952	SNA63157	2	0.04
# SNA55952	SNA70487	1	0.02
# SNA55952	SNA72163	1	0.02
# SNA55952	SNA80192	1	0.02
# SNA55952	SNA94781	2	0.04
# SNA58915	SNA77101	1	0.02
# SNA58915	SNA81153	1	0.02
# SNA58915	SNA89670	1	0.02
# SNA58915	SNA93730	1	0.02
# SNA58915	SNA93860	1	0.02
# SNA58915	SNA99873	1	0.02
# SNA59903	SNA70487	1	0.02
# SNA59903	SNA72163	1	0.02
# SNA62203	SNA63157	1	0.02
# SNA63157	SNA69641	1	0.02
# SNA63157	SNA70487	2	0.04
# SNA63157	SNA80192	1	0.02
# SNA63157	SNA84406	1	0.02
# SNA69641	SNA70487	1	0.02
# SNA69641	SNA80192	1	0.02
# SNA69641	SNA90258	1	0.02
# SNA70487	SNA72163	1	0.02
# SNA70487	SNA84406	1	0.02
# SNA70487	SNA99873	1	0.02
# SNA80064	SNA86836	1	0.02
# SNA80064	SNA99873	1	0.02
# SNA80192	SNA84406	1	0.02
# SNA80192	SNA85662	2	0.04
# SNA80192	SNA90258	2	0.04
# SNA80192	SNA91554	2	0.04
# SNA80192	SNA93860	1	0.02
# SNA80192	SNA99873	1	0.02
# SNA81153	SNA89670	1	0.02
# SNA81153	SNA93730	1	0.02
# SNA83730	SNA85034	1	0.02
# SNA84406	SNA93860	1	0.02
# SNA85662	SNA90258	1	0.02
# SNA85662	SNA91554	1	0.02
# SNA86836	SNA99873	1	0.02
# SNA89670	SNA93730	1	0.02
# SNA90258	SNA91554	1	0.02
# SNA90258	SNA99873	1	0.02
# SNA93641	SNA99873	2	0.04

# %%
### Make sure 1st job output directory is clear in HDFS
# !bin/hdfs dfs -rm -r hw_3_5_tmp_output
#!bin/hdfs dfs -ls
# Out:
# 16/01/31 21:51:08 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 21:51:08 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted hw_3_5_tmp_output

# %%
# %%bash
# #Run the word count job in Hadoop with a single reducer
# time bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -D stream.num.map.output.key.fields=1 \
# -D mapred.output.key.comparator.class=org.apache.hadoop.mapred.lib.KeyFieldBasedComparator \
# -D mapred.text.key.comparator.options='-k1,1' \
# -file ./mapper.py    -mapper ./mapper.py \
# -file ./reducer.py   -reducer ./reducer.py \
# -input /user/nicholashamlin/ProductPurchaseData.txt -output /user/nicholashamlin/hw_3_5_tmp_output
# Out:
# packageJobJar: [./mapper.py, ./reducer.py, /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/hadoop-unjar8690400405891256203/] [] /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/streamjob4444416516453029948.jar tmpDir=null
# 16/01/31 21:51:11 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/01/31 21:51:11 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 21:51:12 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 21:51:12 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 21:51:13 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/01/31 21:51:13 INFO mapreduce.JobSubmitter: number of splits:2
# 16/01/31 21:51:13 INFO Configuration.deprecation: mapred.text.key.comparator.options is deprecated. Instead, use mapreduce.partition.keycomparator.options
# 16/01/31 21:51:13 INFO Configuration.deprecation: mapred.output.key.comparator.class is deprecated. Instead, use mapreduce.job.output.key.comparator.class
# 16/01/31 21:51:13 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1454033924139_0057
# 16/01/31 21:51:13 INFO impl.YarnClientImpl: Submitted application application_1454033924139_0057
# 16/01/31 21:51:13 INFO mapreduce.Job: The url to track the job: http://Nicholass-MacBook-Pro.local:8088/proxy/application_1454033924139_0057/
# 16/01/31 21:51:13 INFO mapreduce.Job: Running job: job_1454033924139_0057
# 16/01/31 21:51:20 INFO mapreduce.Job: Job job_1454033924139_0057 running in uber mode : false
# 16/01/31 21:51:20 INFO mapreduce.Job:  map 0% reduce 0%
# 16/01/31 21:51:28 INFO mapreduce.Job:  map 50% reduce 0%
# 16/01/31 21:51:29 INFO mapreduce.Job:  map 100% reduce 0%
# 16/01/31 21:51:39 INFO mapreduce.Job:  map 100% reduce 68%
# 16/01/31 21:51:42 INFO mapreduce.Job:  map 100% reduce 69%
# 16/01/31 21:51:45 INFO mapreduce.Job:  map 100% reduce 70%
# 16/01/31 21:51:51 INFO mapreduce.Job:  map 100% reduce 71%
# 16/01/31 21:51:54 INFO mapreduce.Job:  map 100% reduce 72%
# 16/01/31 21:51:57 INFO mapreduce.Job:  map 100% reduce 73%
# 16/01/31 21:52:12 INFO mapreduce.Job:  map 100% reduce 74%
# 16/01/31 21:52:18 INFO mapreduce.Job:  map 100% reduce 75%
# 16/01/31 21:52:24 INFO mapreduce.Job:  map 100% reduce 76%
# 16/01/31 21:52:29 INFO mapreduce.Job:  map 100% reduce 77%
# 16/01/31 21:52:32 INFO mapreduce.Job:  map 100% reduce 78%
# 16/01/31 21:52:38 INFO mapreduce.Job:  map 100% reduce 79%
# 16/01/31 21:52:41 INFO mapreduce.Job:  map 100% reduce 80%
# 16/01/31 21:52:50 INFO mapreduce.Job:  map 100% reduce 81%
# 16/01/31 21:52:56 INFO mapreduce.Job:  map 100% reduce 82%
# 16/01/31 21:53:02 INFO mapreduce.Job:  map 100% reduce 83%
# 16/01/31 21:53:08 INFO mapreduce.Job:  map 100% reduce 84%
# 16/01/31 21:53:11 INFO mapreduce.Job:  map 100% reduce 85%
# 16/01/31 21:53:17 INFO mapreduce.Job:  map 100% reduce 86%
# 16/01/31 21:53:23 INFO mapreduce.Job:  map 100% reduce 87%
# 16/01/31 21:53:30 INFO mapreduce.Job:  map 100% reduce 88%
# 16/01/31 21:53:33 INFO mapreduce.Job:  map 100% reduce 89%
# 16/01/31 21:53:36 INFO mapreduce.Job:  map 100% reduce 90%
# 16/01/31 21:53:45 INFO mapreduce.Job:  map 100% reduce 91%
# 16/01/31 21:53:51 INFO mapreduce.Job:  map 100% reduce 92%
# 16/01/31 21:53:54 INFO mapreduce.Job:  map 100% reduce 93%
# 16/01/31 21:54:00 INFO mapreduce.Job:  map 100% reduce 94%
# 16/01/31 21:54:03 INFO mapreduce.Job:  map 100% reduce 95%
# 16/01/31 21:54:09 INFO mapreduce.Job:  map 100% reduce 96%
# 16/01/31 21:54:12 INFO mapreduce.Job:  map 100% reduce 97%
# 16/01/31 21:54:18 INFO mapreduce.Job:  map 100% reduce 98%
# 16/01/31 21:54:24 INFO mapreduce.Job:  map 100% reduce 99%
# 16/01/31 21:54:26 INFO mapreduce.Job:  map 100% reduce 100%
# 16/01/31 21:54:27 INFO mapreduce.Job: Job job_1454033924139_0057 completed successfully
# 16/01/31 21:54:27 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=42480536
# 		FILE: Number of bytes written=85291512
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=3462847
# 		HDFS: Number of bytes written=51765
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=13468
# 		Total time spent by all reduces in occupied slots (ms)=175761
# 		Total time spent by all map tasks (ms)=13468
# 		Total time spent by all reduce tasks (ms)=175761
# 		Total vcore-milliseconds taken by all map tasks=13468
# 		Total vcore-milliseconds taken by all reduce tasks=175761
# 		Total megabyte-milliseconds taken by all map tasks=13791232
# 		Total megabyte-milliseconds taken by all reduce tasks=179979264
# 	Map-Reduce Framework
# 		Map input records=31101
# 		Map output records=349725
# 		Map output bytes=41642109
# 		Map output materialized bytes=42480542
# 		Input split bytes=234
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=12012
# 		Reduce shuffle bytes=42480542
# 		Reduce input records=349725
# 		Reduce output records=1334
# 		Spilled Records=699450
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=185
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 		Total committed heap usage (bytes)=542638080
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=3462613
# 	File Output Format Counters
# 		Bytes Written=51765
# 16/01/31 21:54:27 INFO streaming.StreamJob: Output directory: /user/nicholashamlin/hw_3_5_tmp_output
#
# real	3m16.820s
# user	0m6.066s
# sys	0m0.492s

# %%
# !bin/hdfs dfs -rm -r hw_3_5_final_output
# Out:
# 16/01/31 22:12:21 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 22:12:22 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted hw_3_5_final_output

# %%
# %%bash
# #Run the sorting job using the output of the previous data in Hadoop with a single reducer
# #cat test_output.txt | head -50 |sort -k 1,1nr -k 2,2
# time bin/hadoop jar share/hadoop/tools/lib/hadoop-streaming-2.6.3.jar \
# -D stream.num.map.output.key.fields=3 \
# -D mapred.output.key.comparator.class=org.apache.hadoop.mapred.lib.KeyFieldBasedComparator \
# -D mapred.text.key.comparator.options='-k 1,1nr -k 2,2 -k 3,3' \
# -file ./mapper2.py    -mapper ./mapper2.py \
# -file ./reducer2.py   -reducer ./reducer2.py \
# -input /user/nicholashamlin/hw_3_5_tmp_output -output /user/nicholashamlin/hw_3_5_final_output
# Out:
# packageJobJar: [./mapper2.py, ./reducer2.py, /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/hadoop-unjar6735917673916079317/] [] /var/folders/rz/drh189k95919thyy3gs3tq400000gn/T/streamjob6303512733266721072.jar tmpDir=null
# 16/01/31 22:12:27 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/01/31 22:12:27 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/01/31 22:12:28 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 22:12:28 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/01/31 22:12:29 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/01/31 22:12:29 INFO mapreduce.JobSubmitter: number of splits:2
# 16/01/31 22:12:29 INFO Configuration.deprecation: mapred.text.key.comparator.options is deprecated. Instead, use mapreduce.partition.keycomparator.options
# 16/01/31 22:12:29 INFO Configuration.deprecation: mapred.output.key.comparator.class is deprecated. Instead, use mapreduce.job.output.key.comparator.class
# 16/01/31 22:12:29 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1454033924139_0062
# 16/01/31 22:12:29 INFO impl.YarnClientImpl: Submitted application application_1454033924139_0062
# 16/01/31 22:12:30 INFO mapreduce.Job: The url to track the job: http://Nicholass-MacBook-Pro.local:8088/proxy/application_1454033924139_0062/
# 16/01/31 22:12:30 INFO mapreduce.Job: Running job: job_1454033924139_0062
# 16/01/31 22:12:37 INFO mapreduce.Job: Job job_1454033924139_0062 running in uber mode : false
# 16/01/31 22:12:37 INFO mapreduce.Job:  map 0% reduce 0%
# 16/01/31 22:12:43 INFO mapreduce.Job:  map 100% reduce 0%
# 16/01/31 22:12:47 INFO mapreduce.Job:  map 100% reduce 100%
# 16/01/31 22:12:48 INFO mapreduce.Job: Job job_1454033924139_0062 completed successfully
# 16/01/31 22:12:48 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=54439
# 		FILE: Number of bytes written=439384
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=56105
# 		HDFS: Number of bytes written=51765
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=7322
# 		Total time spent by all reduces in occupied slots (ms)=2338
# 		Total time spent by all map tasks (ms)=7322
# 		Total time spent by all reduce tasks (ms)=2338
# 		Total vcore-milliseconds taken by all map tasks=7322
# 		Total vcore-milliseconds taken by all reduce tasks=2338
# 		Total megabyte-milliseconds taken by all map tasks=7497728
# 		Total megabyte-milliseconds taken by all reduce tasks=2394112
# 	Map-Reduce Framework
# 		Map input records=1334
# 		Map output records=1334
# 		Map output bytes=51765
# 		Map output materialized bytes=54445
# 		Input split bytes=244
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1334
# 		Reduce shuffle bytes=54445
# 		Reduce input records=1334
# 		Reduce output records=1334
# 		Spilled Records=2668
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=163
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 		Total committed heap usage (bytes)=550502400
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=55861
# 	File Output Format Counters
# 		Bytes Written=51765
# 16/01/31 22:12:48 INFO streaming.StreamJob: Output directory: /user/nicholashamlin/hw_3_5_final_output
#
# real	0m21.707s
# user	0m5.380s
# sys	0m0.396s

# %%
# Examine the output of the job in HDFS and print the results
! echo "HW 3.5 RESULTS:"
! echo ""
! echo "50 Most Frequent Pairs:"
! echo "Product 1   |   Product 2 | Raw Freq. | Support "
# !bin/hdfs dfs -cat hw_3_5_final_output/* | head -50
# Out:
# HW 3.5 RESULTS:
#
# 50 Most Frequent Pairs:
# Product 1   |   Product 2 | Raw Freq. | Support
# 16/01/31 22:14:00 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# DAI62779	ELE17451	1592	0.0511880646925
# FRO40251	SNA80324	1412	0.0454004694383
# DAI75645	FRO40251	1254	0.0403202469374
# FRO40251	GRO85051	1213	0.0390019613517
# DAI62779	GRO73461	1139	0.0366226166361
# DAI75645	SNA80324	1130	0.0363332368734
# DAI62779	FRO40251	1070	0.0344040384554
# DAI62779	SNA80324	923	0.0296775023311
# DAI62779	DAI85309	918	0.0295167357963
# ELE32164	GRO59710	911	0.0292916626475
# DAI62779	DAI75645	882	0.0283592167454
# FRO40251	GRO73461	882	0.0283592167454
# DAI62779	ELE92920	877	0.0281984502106
# FRO40251	FRO92469	835	0.026848011318
# DAI62779	ELE32164	832	0.0267515513971
# DAI75645	GRO73461	712	0.0228931545609
# DAI43223	ELE32164	711	0.022861001254
# DAI62779	GRO30386	709	0.02279669464
# ELE17451	FRO40251	697	0.0224108549564
# DAI85309	ELE99737	659	0.0211890292917
# DAI62779	ELE26917	650	0.020899649529
# GRO21487	GRO73461	631	0.0202887366966
# DAI62779	SNA45677	604	0.0194205974084
# ELE17451	SNA80324	597	0.0191955242597
# DAI62779	GRO71621	595	0.0191312176457
# DAI62779	SNA55762	593	0.0190669110318
# DAI62779	DAI83733	586	0.018841837883
# ELE17451	GRO73461	580	0.0186489180412
# GRO73461	SNA80324	562	0.0180701585158
# DAI62779	GRO59710	561	0.0180380052088
# DAI62779	FRO80039	550	0.0176843188322
# DAI75645	ELE17451	547	0.0175878589113
# DAI62779	SNA93860	537	0.0172663258416
# DAI55148	DAI62779	526	0.016912639465
# DAI43223	GRO59710	512	0.0164624931674
# ELE17451	ELE32164	511	0.0164303398605
# DAI62779	SNA18336	506	0.0162695733256
# ELE32164	GRO73461	486	0.0156265071863
# DAI62779	FRO78087	482	0.0154978939584
# DAI85309	ELE17451	482	0.0154978939584
# DAI62779	GRO94758	479	0.0154014340375
# DAI62779	GRO21487	471	0.0151442075817
# GRO85051	SNA80324	471	0.0151442075817
# ELE17451	GRO30386	468	0.0150477476608
# FRO85978	SNA95666	463	0.014886981126
# DAI62779	FRO19221	462	0.014854827819
# DAI62779	GRO46854	461	0.0148226745121
# DAI43223	DAI62779	459	0.0147583678981
# ELE92920	SNA18336	455	0.0146297546703
# DAI88079	FRO40251	446	0.0143403749076
# cat: Unable to write to output stream.

# %% [markdown]
# ###End of Submission
